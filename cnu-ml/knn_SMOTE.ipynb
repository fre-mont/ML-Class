# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
from matplotlib import font_manager, rc

# 한글깨짐 폰트 설정
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()  
rc('font', family=font_name)

# %%
train_data = pd.read_csv("train.csv")
test_data = pd.read_csv("test.csv")

# %%
test_data.shape
# Out:
# (26072, 17)

# %%
train_data.head()
# Out:
#       id     순번 계약구분  재계약횟수  거주개월    아파트 이름  아파트 ID  아파트 평점  호실고유번호  층  ...  \
# 0  61187   9167   해지      3    75     용지아파트       2       7   61188  9  ...
# 1  70016  10398   유효     10   222     용지아파트       2       7   70016  7  ...
# 2  52239   7859   유효      3    80     용지아파트       2       7   52233  2  ...
# 3  85470  12689   유효     10   222  지산5단지아파트       3       8   85460  6  ...
# 4   7941   1161   해지      7   157    비둘기아파트       1       5    4750  8  ...
#
#      퇴거연도  거주연도   월세(원)    보증금(원)  대표나이  나이  성별  결혼여부  거주자 수  move_out
# 0  2012.0  2008   40300   1897000    92  79   남    미혼      1         1
# 1     NaN  2009   64700   4320000    75  63   남    기혼      2         1
# 2     NaN  2015   36700   1954000    81  75   남    기혼      2         1
# 3     NaN  2019   66600   3116000    72  70   여    미혼      1         1
# 4  2015.0  2015  146300  10259000    66  60   여    미혼      3         0
#
# [5 rows x 24 columns]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60832 entries, 0 to 60831
# Data columns (total 24 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        60832 non-null  int64
#  1   순번        60832 non-null  int64
#  2   계약구분      60832 non-null  object
#  3   재계약횟수     60832 non-null  int64
#  4   거주개월      60832 non-null  int64
#  5   아파트 이름    60832 non-null  object
#  6   아파트 ID    60832 non-null  int64
#  7   아파트 평점    60832 non-null  int64
#  8   호실고유번호    60832 non-null  int64
#  9   층         60832 non-null  int64
#  10  평형대       60832 non-null  int64
#  11  계약자고유번호   60832 non-null  int64
#  12  계약서고유번호   60832 non-null  int64
#  13  입주연도      60832 non-null  int64
#  14  퇴거연도      18033 non-null  float64
#  15  거주연도      60832 non-null  int64
#  16  월세(원)     60832 non-null  int64
#  17  보증금(원)    60832 non-null  int64
#  18  대표나이      60832 non-null  int64
#  19  나이        60832 non-null  int64
#  20  성별        60832 non-null  object
#  21  결혼여부      60832 non-null  object
#  22  거주자 수     60832 non-null  int64
#  23  move_out  60832 non-null  int64
# dtypes: float64(1), int64(19), object(4)
# memory usage: 11.1+ MB

# %%
# 복사본 생성 
train = train_data.copy()
test = test_data.copy()

# %%
# 수치형 데이터만 출력 
train.hist(bins=50, figsize=(20, 15))

# target이 불균형 데이터셋
# Out:
# array([[<AxesSubplot:title={'center':'id'}>,
#         <AxesSubplot:title={'center':'순번'}>,
#         <AxesSubplot:title={'center':'재계약횟수'}>,
#         <AxesSubplot:title={'center':'거주개월'}>],
#        [<AxesSubplot:title={'center':'아파트 ID'}>,
#         <AxesSubplot:title={'center':'아파트 평점'}>,
#         <AxesSubplot:title={'center':'호실고유번호'}>,
#         <AxesSubplot:title={'center':'층'}>],
#        [<AxesSubplot:title={'center':'평형대'}>,
#         <AxesSubplot:title={'center':'계약자고유번호'}>,
#         <AxesSubplot:title={'center':'계약서고유번호'}>,
#         <AxesSubplot:title={'center':'입주연도'}>],
#        [<AxesSubplot:title={'center':'퇴거연도'}>,
#         <AxesSubplot:title={'center':'거주연도'}>,
#         <AxesSubplot:title={'center':'월세(원)'}>,
#         <AxesSubplot:title={'center':'보증금(원)'}>],
#        [<AxesSubplot:title={'center':'대표나이'}>,
#         <AxesSubplot:title={'center':'나이'}>,
#         <AxesSubplot:title={'center':'거주자 수'}>,
#         <AxesSubplot:title={'center':'move_out'}>]], dtype=object)

# %%
# 불필요한 columns 제거 
train = train.drop(['id', '순번', '호실고유번호', '계약자고유번호', '계약서고유번호'], axis=1)
test = test.drop(['id', '순번', '호실고유번호', '계약자고유번호', '계약서고유번호'], axis=1)

# %%
print(train['아파트 이름'].value_counts())
print()
print(train['아파트 ID'].value_counts())

# 1 : 비둘기 아파트
# 2 : 용지아파트
# 3 : 지산5단지아파트
# 4 : 까치 아파트
# 5 : 강남아파트 
# 아파트 ID는 아파트이름에 대한 범주를 가짐 
train = train.drop(['아파트 이름'], axis=1)
test = test.drop(['아파트 이름'], axis=1)
# Out:
# 비둘기아파트      25228
# 용지아파트       23792
# 지산5단지아파트     9591
# 까치아파트        1329
# 강남아파트         892
# Name: 아파트 이름, dtype: int64
#
# 1    25228
# 2    23792
# 3     9591
# 4     1329
# 5      892
# Name: 아파트 ID, dtype: int64

# %%
train.hist(bins=50, figsize=(10, 10))
# Out:
# array([[<AxesSubplot:title={'center':'재계약횟수'}>,
#         <AxesSubplot:title={'center':'거주개월'}>,
#         <AxesSubplot:title={'center':'아파트 ID'}>,
#         <AxesSubplot:title={'center':'아파트 평점'}>],
#        [<AxesSubplot:title={'center':'층'}>,
#         <AxesSubplot:title={'center':'평형대'}>,
#         <AxesSubplot:title={'center':'입주연도'}>,
#         <AxesSubplot:title={'center':'퇴거연도'}>],
#        [<AxesSubplot:title={'center':'거주연도'}>,
#         <AxesSubplot:title={'center':'월세(원)'}>,
#         <AxesSubplot:title={'center':'보증금(원)'}>,
#         <AxesSubplot:title={'center':'대표나이'}>],
#        [<AxesSubplot:title={'center':'나이'}>,
#         <AxesSubplot:title={'center':'거주자 수'}>,
#         <AxesSubplot:title={'center':'move_out'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ### 결측치 처리

# %%
train.describe()
# Out:
#               재계약횟수          거주개월        아파트 ID        아파트 평점             층  \
# count  60832.000000  60832.000000  60832.000000  60832.000000  60832.000000
# mean       7.380425    174.313914      1.830632      6.393773      7.884896
# std        2.761137     64.803830      0.873536      1.282835      4.270328
# min        1.000000      1.000000      1.000000      5.000000      1.000000
# 25%        5.000000    126.000000      1.000000      5.000000      4.000000
# 50%        8.000000    196.000000      2.000000      7.000000      8.000000
# 75%       10.000000    222.000000      2.000000      7.000000     12.000000
# max       12.000000    323.000000      5.000000     10.000000     15.000000
#
#                 평형대          입주연도          퇴거연도          거주연도          월세(원)  \
# count  60832.000000  60832.000000  18033.000000  60832.000000   60832.000000
# mean      13.289256   2005.245874   2015.985360   2013.989052   57683.088177
# std        2.387789      4.840107      3.144728      3.730135   30533.036487
# min       12.000000   1994.000000   2008.000000   2008.000000   31300.000000
# 25%       12.000000   2002.000000   2014.000000   2011.000000   40300.000000
# 50%       12.000000   2003.000000   2017.000000   2014.000000   43600.000000
# 75%       15.000000   2008.000000   2019.000000   2017.000000   63600.000000
# max       19.000000   2020.000000   2020.000000   2020.000000  311080.000000
#
#              보증금(원)          대표나이            나이         거주자 수      move_out
# count  6.083200e+04  60832.000000  60832.000000  60832.000000  60832.000000
# mean   3.385542e+06     66.665900     59.654951      1.655428      0.951506
# std    2.378867e+06     12.941232     13.270605      0.929361      0.214810
# min    1.520000e+06     21.000000     20.000000      1.000000      0.000000
# 25%    1.954000e+06     59.000000     51.000000      1.000000      1.000000
# 50%    2.144000e+06     66.000000     59.000000      1.000000      1.000000
# 75%    3.824000e+06     76.000000     69.000000      2.000000      1.000000
# max    1.853640e+07    121.000000    120.000000     10.000000      1.000000

# %%
train.isnull().sum()  # 50%이상 결측값 => 제거
# Out:
# 계약구분            0
# 재계약횟수           0
# 거주개월            0
# 아파트 ID          0
# 아파트 평점          0
# 층               0
# 평형대             0
# 입주연도            0
# 퇴거연도        42799
# 거주연도            0
# 월세(원)           0
# 보증금(원)          0
# 대표나이            0
# 나이              0
# 성별              0
# 결혼여부            0
# 거주자 수           0
# move_out        0
# dtype: int64

# %%
# 퇴거연도에 42799 결측치 존재 => 거주개월과 입주연도로 대략적인 유추 가능! 

print(train['거주개월'] / 12)
print()
print(train['퇴거연도'] - train['입주연도'])  
# 즉 퇴거연도는 입주연도 + 거주개월/12
# Out:
# 0         6.250000
# 1        18.500000
# 2         6.666667
# 3        18.500000
# 4        13.083333
#            ...
# 60827    20.083333
# 60828    18.500000
# 60829     7.333333
# 60830    19.500000
# 60831     7.833333
# Name: 거주개월, Length: 60832, dtype: float64
#
# 0         7.0
# 1         NaN
# 2         NaN
# 3         NaN
# 4        13.0
#          ...
# 60827     NaN
# 60828     NaN
# 60829     7.0
# 60830     NaN
# 60831     7.0
# Length: 60832, dtype: float64

# %%
train['퇴거연도'] = train['퇴거연도'].fillna(train['입주연도'] + train['거주개월'] / 12).astype(int)
print(train['퇴거연도'])

test['퇴거연도'] = test['퇴거연도'].fillna(test['입주연도'] + test['거주개월']/12).astype(int)
print(test['퇴거연도'])
# Out:
# 0        2012
# 1        2021
# 2        2020
# 3        2021
# 4        2015
#          ...
# 60827    2021
# 60828    2021
# 60829    2018
# 60830    2021
# 60831    2015
# Name: 퇴거연도, Length: 60832, dtype: int32
# 0        2011
# 1        2021
# 2        2021
# 3        2021
# 4        2020
#          ...
# 26067    2021
# 26068    2021
# 26069    2021
# 26070    2021
# 26071    2020
# Name: 퇴거연도, Length: 26072, dtype: int32

# %%
print(train.isnull().sum())
print()
print(test.isnull().sum())

# 결측치 처리 완료
# Out:
# 계약구분        0
# 재계약횟수       0
# 거주개월        0
# 아파트 ID      0
# 아파트 평점      0
# 층           0
# 평형대         0
# 입주연도        0
# 퇴거연도        0
# 거주연도        0
# 월세(원)       0
# 보증금(원)      0
# 대표나이        0
# 나이          0
# 성별          0
# 결혼여부        0
# 거주자 수       0
# move_out    0
# dtype: int64
#
# 계약구분      0
# 재계약횟수     0
# 거주개월      0
# 아파트 ID    0
# 아파트 평점    0
# 층         0
# 평형대       0
# 입주연도      0
# 퇴거연도      0
# 거주연도      0
# 월세(원)     0
# 보증금(원)    0
# 대표나이      0
# 나이        0
# 성별        0
# 결혼여부      0
# 거주자 수     0
# dtype: int64

# %%
# 방법 1. 

# train = train.drop(['퇴거연도'], axis=1)
# test = test.drop(['퇴거연도'], axis=1)

# %%
# 방법 2. 

# from sklearn.impute import KNNImputer
# 인접 이웃의 가중 또는 가중 평균을 사용해 대치
# imputer = KNNImputer(n_neighbors=3)
# train_cat = train.select_dtypes(object).columns
# train_num = train.drop(train_cat, axis=1)
# test_num = test.drop(train_cat, axis=1)

# train_impute = imputer.fit_transform(train_num).astype(int)
# test_impute = imputer.fit_transform(test_num).astype(int)

# train_num = pd.DataFrame(train_impute, index=train_num.index, columns=train_num.columns)
# test_num = pd.DataFrame(test_impute, index=test_num.index, columns=test_num.columns)

# train = pd.concat([train_num, train.select_dtypes(object)], axis=1)
# test = pd.concat([test_num, test.select_dtypes(object)], axis=1)

# %%
train.corr()['move_out']
# Out:
# 재계약횟수       0.223704
# 거주개월        0.217926
# 아파트 ID      0.019568
# 아파트 평점      0.019963
# 층           0.005402
# 평형대         0.023630
# 입주연도        0.004543
# 퇴거연도        0.412519
# 거주연도       -0.015578
# 월세(원)      -0.021827
# 보증금(원)     -0.021084
# 대표나이        0.020510
# 나이          0.015623
# 거주자 수      -0.061058
# move_out    1.000000
# Name: move_out, dtype: float64

# %% [markdown]
# ### 원핫인코딩

# %%
train.select_dtypes(object) 
# 모두 2개의 범주를 가짐(0 또는 1)
# Out:
#       계약구분 성별 결혼여부
# 0       해지  남   미혼
# 1       유효  남   기혼
# 2       유효  남   기혼
# 3       유효  여   미혼
# 4       해지  여   미혼
# ...    ... ..  ...
# 60827   유효  여   미혼
# 60828   유효  남   미혼
# 60829   해지  여   미혼
# 60830   유효  남   기혼
# 60831   해지  남   미혼
#
# [60832 rows x 3 columns]

# %%
# 3개의 변수는 "범주형 변수"로 보이므로, get_dummies() 함수 사용하여 전처리
#drop_first=True 옵션으로 가변수의 첫번째 변수를 자동 삭제하여 가변수 함정(dummy trap) 방지
train_data = pd.get_dummies(train, drop_first=True)
print("train_data 특성:\n", list(train.columns))

print("-"*50)

test_data = pd.get_dummies(test, drop_first=True)
print("test_data 후의 특성:\n", list(test.columns))
# Out:
# train_data 특성:
#  ['계약구분', '재계약횟수', '거주개월', '아파트 ID', '아파트 평점', '층', '평형대', '입주연도', '퇴거연도', '거주연도', '월세(원)', '보증금(원)', '대표나이', '나이', '성별', '결혼여부', '거주자 수', 'move_out']
# --------------------------------------------------
# test_data 후의 특성:
#  ['계약구분', '재계약횟수', '거주개월', '아파트 ID', '아파트 평점', '층', '평형대', '입주연도', '퇴거연도', '거주연도', '월세(원)', '보증금(원)', '대표나이', '나이', '성별', '결혼여부', '거주자 수']

# %%
train_data.head()

# 미혼 1 기혼 0
# 해지 1 유효 0
# 여 1 남 0
# Out:
#    재계약횟수  거주개월  아파트 ID  아파트 평점  층  평형대  입주연도  퇴거연도  거주연도   월세(원)    보증금(원)  \
# 0      3    75       2       7  9   12  2005  2012  2008   40300   1897000
# 1     10   222       2       7  7   12  2003  2021  2009   64700   4320000
# 2      3    80       2       7  2   12  2014  2020  2015   36700   1954000
# 3     10   222       3       8  6   19  2003  2021  2019   66600   3116000
# 4      7   157       1       5  8   19  2002  2015  2015  146300  10259000
#
#    대표나이  나이  거주자 수  move_out  계약구분_해지  성별_여  결혼여부_미혼
# 0    92  79      1         1        1     0        1
# 1    75  63      2         1        0     0        0
# 2    81  75      2         1        0     0        0
# 3    72  70      1         1        0     1        1
# 4    66  60      3         0        1     1        1

# %%
## 특징-정답데이터 분리
X_train = train_data.drop(['move_out'], axis=1)
y_train = train_data['move_out']

print(X_train.shape)
print(y_train.shape)

print(test_data.shape)
# Out:
# (60832, 17)
# (60832,)
# (26072, 17)

# %%
# 표준화 작업
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(test_data)

# %%
X_train = pd.DataFrame(X_scaled, index=X_train.index,
                       columns=X_train.columns)

X_test = pd.DataFrame(X_test, index=test_data.index, columns=test_data.columns)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (60832, 17)
# (26072, 17)

# %%
# # 검증세트 필요시
# from sklearn.model_selection import StratifiedShuffleSplit
# split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

# # 각 분할 결과의 index를 바탕으로 strat_train_set과 strat_test_set 생성
# for train_index, test_index in split.split(X_train, y_train):
#     strat_train_set = X_train.loc[train_index]
#     strat_valid_set = X_train.loc[test_index]

# print(strat_train_set.shape)
# print(strat_valid_set.shape)

# # train_set의 소득카테고리별 비율
# print(strat_train_set["move_out"].value_counts() / len(strat_train_set))

# print('-'*40)

# # 전체 데이터의 각 계층별 비율
# print(train["move_out"].value_counts() / len(train))

# %% [markdown]
# #### 데이터 준비 끝 -> X_train, y_train, X_valid, y_valid, X_test

# %% [markdown]
# ### 모델링

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import cross_val_score

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

# 앙상블 모델 
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import ExtraTreesClassifier

# 기타 
import xgboost as xgb
import catboost

# %%
knn_clf = KNeighborsClassifier(n_neighbors=6)
dt_clf = DecisionTreeClassifier(max_depth=8)
lr_clf = LogisticRegression()

# 배깅 
rf_clf = RandomForestClassifier(n_estimators=300, random_state=42)
et_clf = ExtraTreesClassifier(n_estimators=300, random_state=42)

# 부스팅 
gb_clf = GradientBoostingClassifier(learning_rate=0.05)
ada_clf = AdaBoostClassifier(n_estimators=100)

xgb_clf = xgb.XGBClassifier()
cat_clf = catboost.CatBoostClassifier(iterations=300, learning_rate=0.1)

# 보팅
vot_clf = VotingClassifier(estimators=[(
    "lr", dt_clf), ("rf", rf_clf), ("gbm", gb_clf), ("ada", ada_clf)], voting="soft")

# %%
def model(name, x):
    x.fit(X_train, y_train)
    train_pred = x.predict(X_train)
    train_scores = roc_auc_score(y_train, train_pred)
    scores = cross_val_score(x, X_train, y_train, cv=5, scoring='roc_auc')  # 교차검증 
    
    print(name, train_scores, scores.mean())
    print(confusion_matrix(y_train, train_pred))  # 혼동행렬 출력하기

# %%
# 대충 쓸만한 모델 찾기 위한 작업 
model("knn", knn_clf)  # baseline 모델
# Out:
# knn 0.6795869035717904 0.8889645911219617
# [[ 1080  1870]
#  [  401 57481]]

# %%
model("dt", dt_clf)
model("rf", rf_clf)
model('lr', lr_clf)
model('et', et_clf)
model("xgb", xgb_clf)
model("gbm", gb_clf)
model("ada", ada_clf)
model("voting", vot_clf)
model("cat", cat_clf)
# Out:
# dt 0.8061016949152542 0.9929514912729133
# [[ 1806  1144]
#  [    0 57882]]
# rf 1.0 0.998968572220374
# [[ 2950     0]
#  [    0 57882]]
# lr 1.0 1.0
# [[ 2950     0]
#  [    0 57882]]
# et 1.0 0.9988659732779048
# [[ 2950     0]
#  [    0 57882]]
# [16:09:44] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "scoring" } are not used.
#
# [16:09:45] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "scoring" } are not used.
#
# [16:09:45] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "scoring" } are not used.
#
# [16:09:46] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "scoring" } are not used.
#
# [16:09:46] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "scoring" } are not used.
#
# [16:09:47] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "scoring" } are not used.
#
# xgb 1.0 1.0
# [[ 2950     0]
#  [    0 57882]]
# gbm 1.0 1.0
# [[ 2950     0]
#  [    0 57882]]
# ada 1.0 1.0
# [[ 2950     0]
#  [    0 57882]]
# voting 1.0 0.9999952854756218
# [[ 2950     0]
#  [    0 57882]]
# 0:	learn: 0.4142231	total: 12.9ms	remaining: 3.86s
# 1:	learn: 0.2772248	total: 24.5ms	remaining: 3.65s
# 2:	learn: 0.1900063	total: 36.8ms	remaining: 3.64s
# 3:	learn: 0.1335018	total: 49ms	remaining: 3.63s
# 4:	learn: 0.1102210	total: 61ms	remaining: 3.6s
# 5:	learn: 0.0976191	total: 72.5ms	remaining: 3.55s
# 6:	learn: 0.0837197	total: 84.8ms	remaining: 3.55s
# 7:	learn: 0.0773969	total: 97.4ms	remaining: 3.56s
# 8:	learn: 0.0651834	total: 111ms	remaining: 3.59s
# 9:	learn: 0.0606928	total: 123ms	remaining: 3.57s
# 10:	learn: 0.0582062	total: 135ms	remaining: 3.55s
# 11:	learn: 0.0526524	total: 147ms	remaining: 3.53s
# 12:	learn: 0.0486946	total: 159ms	remaining: 3.51s
# 13:	learn: 0.0439761	total: 171ms	remaining: 3.5s
# 14:	learn: 0.0408725	total: 184ms	remaining: 3.5s
# 15:	learn: 0.0370333	total: 198ms	remaining: 3.51s
# 16:	learn: 0.0347394	total: 210ms	remaining: 3.49s
# 17:	learn: 0.0311954	total: 222ms	remaining: 3.48s
# 18:	learn: 0.0285457	total: 236ms	remaining: 3.48s
# 19:	learn: 0.0275687	total: 248ms	remaining: 3.47s
# 20:	learn: 0.0242063	total: 260ms	remaining: 3.46s
# 21:	learn: 0.0234960	total: 273ms	remaining: 3.45s
# 22:	learn: 0.0223456	total: 287ms	remaining: 3.45s
# 23:	learn: 0.0207167	total: 299ms	remaining: 3.44s
# 24:	learn: 0.0197019	total: 311ms	remaining: 3.42s
# 25:	learn: 0.0181703	total: 323ms	remaining: 3.4s
# 26:	learn: 0.0163854	total: 335ms	remaining: 3.39s
# 27:	learn: 0.0152994	total: 347ms	remaining: 3.37s
# 28:	learn: 0.0143234	total: 359ms	remaining: 3.36s
# 29:	learn: 0.0131729	total: 371ms	remaining: 3.34s
# 30:	learn: 0.0119457	total: 384ms	remaining: 3.33s
# 31:	learn: 0.0112223	total: 396ms	remaining: 3.32s
# 32:	learn: 0.0105816	total: 408ms	remaining: 3.3s
# 33:	learn: 0.0100055	total: 420ms	remaining: 3.29s
# 34:	learn: 0.0093663	total: 433ms	remaining: 3.27s
# 35:	learn: 0.0089922	total: 445ms	remaining: 3.26s
# 36:	learn: 0.0084478	total: 456ms	remaining: 3.24s
# 37:	learn: 0.0079511	total: 468ms	remaining: 3.23s
# 38:	learn: 0.0076046	total: 480ms	remaining: 3.21s
# 39:	learn: 0.0073973	total: 492ms	remaining: 3.2s
# 40:	learn: 0.0069607	total: 504ms	remaining: 3.18s
# 41:	learn: 0.0065767	total: 517ms	remaining: 3.17s
# 42:	learn: 0.0059158	total: 529ms	remaining: 3.16s
# 43:	learn: 0.0056154	total: 541ms	remaining: 3.15s
# 44:	learn: 0.0054027	total: 553ms	remaining: 3.13s
# 45:	learn: 0.0053139	total: 565ms	remaining: 3.12s
# 46:	learn: 0.0050256	total: 577ms	remaining: 3.1s
# 47:	learn: 0.0047913	total: 589ms	remaining: 3.09s
# 48:	learn: 0.0045468	total: 601ms	remaining: 3.08s
# 49:	learn: 0.0043185	total: 614ms	remaining: 3.07s
# 50:	learn: 0.0041430	total: 626ms	remaining: 3.06s
# 51:	learn: 0.0038112	total: 638ms	remaining: 3.04s
# 52:	learn: 0.0036081	total: 650ms	remaining: 3.03s
# 53:	learn: 0.0035536	total: 662ms	remaining: 3.01s
# 54:	learn: 0.0034813	total: 674ms	remaining: 3s
# 55:	learn: 0.0032839	total: 685ms	remaining: 2.99s
# 56:	learn: 0.0032320	total: 697ms	remaining: 2.97s
# 57:	learn: 0.0031118	total: 709ms	remaining: 2.96s
# 58:	learn: 0.0029463	total: 721ms	remaining: 2.94s
# 59:	learn: 0.0029464	total: 731ms	remaining: 2.92s
# 60:	learn: 0.0029331	total: 742ms	remaining: 2.91s
# 61:	learn: 0.0029066	total: 753ms	remaining: 2.89s
# 62:	learn: 0.0027081	total: 766ms	remaining: 2.88s
# 63:	learn: 0.0026417	total: 778ms	remaining: 2.87s
# 64:	learn: 0.0026417	total: 788ms	remaining: 2.85s
# 65:	learn: 0.0025070	total: 800ms	remaining: 2.84s
# 66:	learn: 0.0024402	total: 812ms	remaining: 2.82s
# 67:	learn: 0.0024403	total: 822ms	remaining: 2.81s
# 68:	learn: 0.0023437	total: 835ms	remaining: 2.79s
# 69:	learn: 0.0022369	total: 847ms	remaining: 2.78s
# 70:	learn: 0.0021118	total: 859ms	remaining: 2.77s
# 71:	learn: 0.0020212	total: 870ms	remaining: 2.76s
# 72:	learn: 0.0018783	total: 882ms	remaining: 2.74s
# 73:	learn: 0.0018397	total: 894ms	remaining: 2.73s
# 74:	learn: 0.0017690	total: 906ms	remaining: 2.72s
# 75:	learn: 0.0016995	total: 918ms	remaining: 2.71s
# 76:	learn: 0.0016285	total: 930ms	remaining: 2.69s
# 77:	learn: 0.0015676	total: 942ms	remaining: 2.68s
# 78:	learn: 0.0015676	total: 953ms	remaining: 2.66s
# 79:	learn: 0.0015676	total: 963ms	remaining: 2.65s
# 80:	learn: 0.0015675	total: 973ms	remaining: 2.63s
# 81:	learn: 0.0014530	total: 985ms	remaining: 2.62s
# 82:	learn: 0.0014530	total: 996ms	remaining: 2.6s
# 83:	learn: 0.0014000	total: 1.01s	remaining: 2.59s
# 84:	learn: 0.0013419	total: 1.02s	remaining: 2.58s
# 85:	learn: 0.0013419	total: 1.03s	remaining: 2.57s
# 86:	learn: 0.0012968	total: 1.04s	remaining: 2.56s
# 87:	learn: 0.0012968	total: 1.05s	remaining: 2.54s
# 88:	learn: 0.0012969	total: 1.07s	remaining: 2.53s
# 89:	learn: 0.0012968	total: 1.08s	remaining: 2.51s
# 90:	learn: 0.0012967	total: 1.09s	remaining: 2.5s
# 91:	learn: 0.0012619	total: 1.1s	remaining: 2.49s
# 92:	learn: 0.0012618	total: 1.11s	remaining: 2.47s
# 93:	learn: 0.0012618	total: 1.12s	remaining: 2.46s
# 94:	learn: 0.0012617	total: 1.13s	remaining: 2.44s
# 95:	learn: 0.0012122	total: 1.14s	remaining: 2.43s
# 96:	learn: 0.0012122	total: 1.16s	remaining: 2.42s
# 97:	learn: 0.0012121	total: 1.17s	remaining: 2.4s
# 98:	learn: 0.0012121	total: 1.18s	remaining: 2.39s
# 99:	learn: 0.0012120	total: 1.19s	remaining: 2.37s
# 100:	learn: 0.0011710	total: 1.2s	remaining: 2.36s
# 101:	learn: 0.0011251	total: 1.21s	remaining: 2.35s
# 102:	learn: 0.0011250	total: 1.22s	remaining: 2.34s
# 103:	learn: 0.0011249	total: 1.23s	remaining: 2.32s
# 104:	learn: 0.0011249	total: 1.24s	remaining: 2.31s
# 105:	learn: 0.0010814	total: 1.25s	remaining: 2.3s
# 106:	learn: 0.0010813	total: 1.26s	remaining: 2.28s
# 107:	learn: 0.0010812	total: 1.28s	remaining: 2.27s
# 108:	learn: 0.0010811	total: 1.29s	remaining: 2.25s
# 109:	learn: 0.0010471	total: 1.3s	remaining: 2.24s
# 110:	learn: 0.0010471	total: 1.31s	remaining: 2.23s
# 111:	learn: 0.0010471	total: 1.32s	remaining: 2.21s
# 112:	learn: 0.0010471	total: 1.33s	remaining: 2.2s
# 113:	learn: 0.0010470	total: 1.34s	remaining: 2.19s
# 114:	learn: 0.0010470	total: 1.35s	remaining: 2.17s
# 115:	learn: 0.0010468	total: 1.36s	remaining: 2.16s
# 116:	learn: 0.0010468	total: 1.37s	remaining: 2.15s
# 117:	learn: 0.0010468	total: 1.38s	remaining: 2.13s
# 118:	learn: 0.0010467	total: 1.39s	remaining: 2.12s
# 119:	learn: 0.0010466	total: 1.4s	remaining: 2.1s
# 120:	learn: 0.0010466	total: 1.41s	remaining: 2.09s
# 121:	learn: 0.0010466	total: 1.42s	remaining: 2.08s
# 122:	learn: 0.0010465	total: 1.43s	remaining: 2.06s
# 123:	learn: 0.0010465	total: 1.44s	remaining: 2.05s
# 124:	learn: 0.0010465	total: 1.45s	remaining: 2.04s
# 125:	learn: 0.0010465	total: 1.46s	remaining: 2.02s
# 126:	learn: 0.0010465	total: 1.47s	remaining: 2.01s
# 127:	learn: 0.0010465	total: 1.49s	remaining: 2s
# 128:	learn: 0.0010464	total: 1.5s	remaining: 1.98s
# 129:	learn: 0.0010464	total: 1.5s	remaining: 1.97s
# 130:	learn: 0.0010464	total: 1.51s	remaining: 1.96s
# 131:	learn: 0.0010464	total: 1.53s	remaining: 1.94s
# 132:	learn: 0.0010462	total: 1.54s	remaining: 1.93s
# 133:	learn: 0.0010462	total: 1.55s	remaining: 1.92s
# 134:	learn: 0.0010462	total: 1.56s	remaining: 1.9s
# 135:	learn: 0.0010460	total: 1.57s	remaining: 1.89s
# 136:	learn: 0.0010460	total: 1.58s	remaining: 1.88s
# 137:	learn: 0.0010459	total: 1.59s	remaining: 1.86s
# 138:	learn: 0.0010459	total: 1.6s	remaining: 1.85s
# 139:	learn: 0.0010458	total: 1.61s	remaining: 1.84s
# 140:	learn: 0.0010458	total: 1.62s	remaining: 1.83s
# 141:	learn: 0.0010458	total: 1.63s	remaining: 1.81s
# 142:	learn: 0.0010458	total: 1.64s	remaining: 1.8s
# 143:	learn: 0.0010457	total: 1.65s	remaining: 1.79s
# 144:	learn: 0.0010457	total: 1.66s	remaining: 1.77s
# 145:	learn: 0.0010456	total: 1.67s	remaining: 1.76s
# 146:	learn: 0.0010456	total: 1.68s	remaining: 1.75s
# 147:	learn: 0.0010455	total: 1.69s	remaining: 1.74s
# 148:	learn: 0.0010454	total: 1.7s	remaining: 1.72s
# 149:	learn: 0.0010455	total: 1.71s	remaining: 1.71s
# 150:	learn: 0.0010455	total: 1.72s	remaining: 1.7s
# 151:	learn: 0.0010455	total: 1.73s	remaining: 1.69s
# 152:	learn: 0.0010455	total: 1.74s	remaining: 1.68s
# 153:	learn: 0.0010455	total: 1.75s	remaining: 1.66s
# 154:	learn: 0.0010455	total: 1.76s	remaining: 1.65s
# 155:	learn: 0.0010455	total: 1.77s	remaining: 1.64s
# 156:	learn: 0.0010455	total: 1.78s	remaining: 1.62s
# 157:	learn: 0.0010455	total: 1.79s	remaining: 1.61s
# 158:	learn: 0.0010455	total: 1.8s	remaining: 1.6s
# 159:	learn: 0.0010455	total: 1.81s	remaining: 1.59s
# 160:	learn: 0.0010455	total: 1.82s	remaining: 1.57s
# 161:	learn: 0.0010455	total: 1.83s	remaining: 1.56s
# 162:	learn: 0.0010455	total: 1.84s	remaining: 1.55s
# 163:	learn: 0.0010455	total: 1.85s	remaining: 1.54s
# 164:	learn: 0.0010455	total: 1.86s	remaining: 1.53s
# 165:	learn: 0.0010455	total: 1.88s	remaining: 1.51s
# 166:	learn: 0.0010455	total: 1.89s	remaining: 1.5s
# 167:	learn: 0.0010455	total: 1.9s	remaining: 1.49s
# 168:	learn: 0.0010455	total: 1.91s	remaining: 1.48s
# 169:	learn: 0.0010455	total: 1.92s	remaining: 1.47s
# 170:	learn: 0.0010455	total: 1.93s	remaining: 1.45s
# 171:	learn: 0.0010455	total: 1.94s	remaining: 1.44s
# 172:	learn: 0.0010455	total: 1.95s	remaining: 1.43s
# 173:	learn: 0.0010455	total: 1.96s	remaining: 1.42s
# 174:	learn: 0.0010455	total: 1.97s	remaining: 1.4s
# 175:	learn: 0.0010455	total: 1.98s	remaining: 1.39s
# 176:	learn: 0.0010455	total: 1.99s	remaining: 1.38s
# 177:	learn: 0.0010455	total: 2s	remaining: 1.37s
# 178:	learn: 0.0010455	total: 2.01s	remaining: 1.36s
# 179:	learn: 0.0010455	total: 2.02s	remaining: 1.34s
# 180:	learn: 0.0010455	total: 2.03s	remaining: 1.33s
# 181:	learn: 0.0010455	total: 2.04s	remaining: 1.32s
# 182:	learn: 0.0010455	total: 2.05s	remaining: 1.31s
# 183:	learn: 0.0010455	total: 2.06s	remaining: 1.3s
# 184:	learn: 0.0010455	total: 2.07s	remaining: 1.28s
# 185:	learn: 0.0010455	total: 2.08s	remaining: 1.27s
# 186:	learn: 0.0010455	total: 2.09s	remaining: 1.26s
# 187:	learn: 0.0010455	total: 2.1s	remaining: 1.25s
# 188:	learn: 0.0010455	total: 2.11s	remaining: 1.24s
# 189:	learn: 0.0010455	total: 2.12s	remaining: 1.23s
# 190:	learn: 0.0010455	total: 2.13s	remaining: 1.22s
# 191:	learn: 0.0010455	total: 2.14s	remaining: 1.2s
# 192:	learn: 0.0010455	total: 2.15s	remaining: 1.19s
# 193:	learn: 0.0010455	total: 2.16s	remaining: 1.18s
# 194:	learn: 0.0010455	total: 2.17s	remaining: 1.17s
# 195:	learn: 0.0010455	total: 2.18s	remaining: 1.16s
# 196:	learn: 0.0010455	total: 2.19s	remaining: 1.15s
# 197:	learn: 0.0010455	total: 2.2s	remaining: 1.13s
# 198:	learn: 0.0010455	total: 2.21s	remaining: 1.12s
# 199:	learn: 0.0010455	total: 2.22s	remaining: 1.11s
# 200:	learn: 0.0010455	total: 2.23s	remaining: 1.1s
# 201:	learn: 0.0010455	total: 2.24s	remaining: 1.09s
# 202:	learn: 0.0010455	total: 2.25s	remaining: 1.07s
# 203:	learn: 0.0010455	total: 2.26s	remaining: 1.06s
# 204:	learn: 0.0010455	total: 2.27s	remaining: 1.05s
# 205:	learn: 0.0010455	total: 2.28s	remaining: 1.04s
# 206:	learn: 0.0010455	total: 2.29s	remaining: 1.03s
# 207:	learn: 0.0010455	total: 2.3s	remaining: 1.02s
# 208:	learn: 0.0010455	total: 2.31s	remaining: 1.01s
# 209:	learn: 0.0010455	total: 2.32s	remaining: 995ms
# 210:	learn: 0.0010455	total: 2.33s	remaining: 983ms
# 211:	learn: 0.0010455	total: 2.34s	remaining: 972ms
# 212:	learn: 0.0010455	total: 2.35s	remaining: 960ms
# 213:	learn: 0.0010455	total: 2.36s	remaining: 949ms
# 214:	learn: 0.0010455	total: 2.37s	remaining: 937ms
# 215:	learn: 0.0010455	total: 2.38s	remaining: 926ms
# 216:	learn: 0.0010455	total: 2.39s	remaining: 914ms
# 217:	learn: 0.0010455	total: 2.4s	remaining: 903ms
# 218:	learn: 0.0010455	total: 2.41s	remaining: 892ms
# 219:	learn: 0.0010455	total: 2.42s	remaining: 880ms
# 220:	learn: 0.0010455	total: 2.43s	remaining: 869ms
# 221:	learn: 0.0010455	total: 2.44s	remaining: 858ms
# 222:	learn: 0.0010455	total: 2.45s	remaining: 846ms
# 223:	learn: 0.0010455	total: 2.46s	remaining: 835ms
# 224:	learn: 0.0010455	total: 2.47s	remaining: 824ms
# 225:	learn: 0.0010455	total: 2.48s	remaining: 813ms
# 226:	learn: 0.0010455	total: 2.49s	remaining: 801ms
# 227:	learn: 0.0010455	total: 2.5s	remaining: 790ms
# 228:	learn: 0.0010455	total: 2.51s	remaining: 779ms
# 229:	learn: 0.0010455	total: 2.52s	remaining: 767ms
# 230:	learn: 0.0010455	total: 2.53s	remaining: 756ms
# 231:	learn: 0.0010455	total: 2.54s	remaining: 745ms
# 232:	learn: 0.0010455	total: 2.55s	remaining: 734ms
# 233:	learn: 0.0010455	total: 2.56s	remaining: 722ms
# 234:	learn: 0.0010455	total: 2.57s	remaining: 711ms
# 235:	learn: 0.0010455	total: 2.58s	remaining: 700ms
# 236:	learn: 0.0010455	total: 2.59s	remaining: 689ms
# 237:	learn: 0.0010455	total: 2.6s	remaining: 678ms
# 238:	learn: 0.0010455	total: 2.61s	remaining: 667ms
# 239:	learn: 0.0010455	total: 2.62s	remaining: 655ms
# 240:	learn: 0.0010455	total: 2.63s	remaining: 644ms
# 241:	learn: 0.0010455	total: 2.64s	remaining: 633ms
# 242:	learn: 0.0010455	total: 2.65s	remaining: 622ms
# 243:	learn: 0.0010455	total: 2.66s	remaining: 611ms
# 244:	learn: 0.0010455	total: 2.67s	remaining: 600ms
# 245:	learn: 0.0010455	total: 2.68s	remaining: 589ms
# 246:	learn: 0.0010455	total: 2.69s	remaining: 578ms
# 247:	learn: 0.0010455	total: 2.7s	remaining: 566ms
# 248:	learn: 0.0010455	total: 2.71s	remaining: 555ms
# 249:	learn: 0.0010455	total: 2.72s	remaining: 544ms
# 250:	learn: 0.0010455	total: 2.73s	remaining: 533ms
# 251:	learn: 0.0010455	total: 2.74s	remaining: 522ms
# 252:	learn: 0.0010455	total: 2.75s	remaining: 511ms
# 253:	learn: 0.0010455	total: 2.76s	remaining: 500ms
# 254:	learn: 0.0010455	total: 2.77s	remaining: 489ms
# 255:	learn: 0.0010455	total: 2.78s	remaining: 478ms
# 256:	learn: 0.0010455	total: 2.79s	remaining: 467ms
# 257:	learn: 0.0010455	total: 2.8s	remaining: 456ms
# 258:	learn: 0.0010455	total: 2.81s	remaining: 445ms
# 259:	learn: 0.0010455	total: 2.82s	remaining: 434ms
# 260:	learn: 0.0010455	total: 2.83s	remaining: 423ms
# 261:	learn: 0.0010455	total: 2.84s	remaining: 412ms
# 262:	learn: 0.0010455	total: 2.85s	remaining: 402ms
# 263:	learn: 0.0010455	total: 2.86s	remaining: 391ms
# 264:	learn: 0.0010455	total: 2.88s	remaining: 380ms
# 265:	learn: 0.0010455	total: 2.88s	remaining: 369ms
# 266:	learn: 0.0010455	total: 2.9s	remaining: 358ms
# 267:	learn: 0.0010455	total: 2.9s	remaining: 347ms
# 268:	learn: 0.0010455	total: 2.92s	remaining: 336ms
# 269:	learn: 0.0010455	total: 2.92s	remaining: 325ms
# 270:	learn: 0.0010455	total: 2.94s	remaining: 314ms
# 271:	learn: 0.0010455	total: 2.94s	remaining: 303ms
# 272:	learn: 0.0010455	total: 2.96s	remaining: 292ms
# 273:	learn: 0.0010455	total: 2.96s	remaining: 281ms
# 274:	learn: 0.0010455	total: 2.98s	remaining: 271ms
# 275:	learn: 0.0010455	total: 2.99s	remaining: 260ms
# 276:	learn: 0.0010455	total: 3s	remaining: 249ms
# 277:	learn: 0.0010455	total: 3.01s	remaining: 238ms
# 278:	learn: 0.0010455	total: 3.02s	remaining: 227ms
# 279:	learn: 0.0010455	total: 3.03s	remaining: 216ms
# 280:	learn: 0.0010455	total: 3.04s	remaining: 205ms
# 281:	learn: 0.0010455	total: 3.05s	remaining: 195ms
# 282:	learn: 0.0010455	total: 3.06s	remaining: 184ms
# 283:	learn: 0.0010455	total: 3.07s	remaining: 173ms
# 284:	learn: 0.0010455	total: 3.08s	remaining: 162ms
# 285:	learn: 0.0010455	total: 3.09s	remaining: 151ms
# 286:	learn: 0.0010455	total: 3.1s	remaining: 140ms
# 287:	learn: 0.0010455	total: 3.11s	remaining: 130ms
# 288:	learn: 0.0010455	total: 3.12s	remaining: 119ms
# 289:	learn: 0.0010455	total: 3.13s	remaining: 108ms
# 290:	learn: 0.0010455	total: 3.14s	remaining: 97.1ms
# 291:	learn: 0.0010455	total: 3.15s	remaining: 86.3ms
# 292:	learn: 0.0010455	total: 3.16s	remaining: 75.5ms
# 293:	learn: 0.0010455	total: 3.17s	remaining: 64.7ms
# 294:	learn: 0.0010455	total: 3.18s	remaining: 53.9ms
# 295:	learn: 0.0010455	total: 3.19s	remaining: 43.1ms
# 296:	learn: 0.0010455	total: 3.2s	remaining: 32.3ms
# 297:	learn: 0.0010455	total: 3.21s	remaining: 21.5ms
# 298:	learn: 0.0010455	total: 3.22s	remaining: 10.8ms
# 299:	learn: 0.0010455	total: 3.23s	remaining: 0us
# 0:	learn: 0.4177299	total: 12.7ms	remaining: 3.78s
# 1:	learn: 0.2826348	total: 23.4ms	remaining: 3.48s
# 2:	learn: 0.1883202	total: 35.3ms	remaining: 3.49s
# 3:	learn: 0.1431646	total: 46.7ms	remaining: 3.45s
# 4:	learn: 0.1167056	total: 58.2ms	remaining: 3.44s
# 5:	learn: 0.0992845	total: 69.6ms	remaining: 3.41s
# 6:	learn: 0.0844953	total: 80.6ms	remaining: 3.38s
# 7:	learn: 0.0767624	total: 91.7ms	remaining: 3.35s
# 8:	learn: 0.0725851	total: 103ms	remaining: 3.32s
# 9:	learn: 0.0685000	total: 114ms	remaining: 3.3s
# 10:	learn: 0.0617506	total: 125ms	remaining: 3.28s
# 11:	learn: 0.0551958	total: 136ms	remaining: 3.27s
# 12:	learn: 0.0528865	total: 148ms	remaining: 3.26s
# 13:	learn: 0.0503548	total: 160ms	remaining: 3.26s
# 14:	learn: 0.0457913	total: 171ms	remaining: 3.25s
# 15:	learn: 0.0428055	total: 182ms	remaining: 3.24s
# 16:	learn: 0.0392448	total: 194ms	remaining: 3.23s
# 17:	learn: 0.0362064	total: 205ms	remaining: 3.21s
# 18:	learn: 0.0345677	total: 216ms	remaining: 3.2s
# 19:	learn: 0.0295681	total: 228ms	remaining: 3.19s
# 20:	learn: 0.0285214	total: 239ms	remaining: 3.17s
# 21:	learn: 0.0262834	total: 250ms	remaining: 3.16s
# 22:	learn: 0.0237961	total: 262ms	remaining: 3.15s
# 23:	learn: 0.0221900	total: 273ms	remaining: 3.14s
# 24:	learn: 0.0213250	total: 284ms	remaining: 3.12s
# 25:	learn: 0.0207353	total: 296ms	remaining: 3.12s
# 26:	learn: 0.0185864	total: 307ms	remaining: 3.1s
# 27:	learn: 0.0173512	total: 318ms	remaining: 3.09s
# 28:	learn: 0.0158223	total: 330ms	remaining: 3.08s
# 29:	learn: 0.0153322	total: 341ms	remaining: 3.07s
# 30:	learn: 0.0150388	total: 352ms	remaining: 3.05s
# 31:	learn: 0.0141696	total: 363ms	remaining: 3.04s
# 32:	learn: 0.0130596	total: 374ms	remaining: 3.03s
# 33:	learn: 0.0124429	total: 385ms	remaining: 3.01s
# 34:	learn: 0.0117588	total: 397ms	remaining: 3s
# 35:	learn: 0.0112187	total: 409ms	remaining: 3s
# 36:	learn: 0.0107428	total: 420ms	remaining: 2.99s
# 37:	learn: 0.0103885	total: 432ms	remaining: 2.98s
# 38:	learn: 0.0095918	total: 444ms	remaining: 2.97s
# 39:	learn: 0.0086296	total: 455ms	remaining: 2.96s
# 40:	learn: 0.0080684	total: 467ms	remaining: 2.95s
# 41:	learn: 0.0077167	total: 478ms	remaining: 2.94s
# 42:	learn: 0.0073885	total: 489ms	remaining: 2.92s
# 43:	learn: 0.0070164	total: 500ms	remaining: 2.91s
# 44:	learn: 0.0065542	total: 512ms	remaining: 2.9s
# 45:	learn: 0.0065014	total: 522ms	remaining: 2.88s
# 46:	learn: 0.0064216	total: 533ms	remaining: 2.87s
# 47:	learn: 0.0059194	total: 544ms	remaining: 2.85s
# 48:	learn: 0.0056152	total: 555ms	remaining: 2.84s
# 49:	learn: 0.0051919	total: 567ms	remaining: 2.83s
# 50:	learn: 0.0050452	total: 578ms	remaining: 2.82s
# 51:	learn: 0.0048004	total: 589ms	remaining: 2.81s
# 52:	learn: 0.0043906	total: 600ms	remaining: 2.8s
# 53:	learn: 0.0041507	total: 612ms	remaining: 2.79s
# 54:	learn: 0.0038752	total: 624ms	remaining: 2.78s
# 55:	learn: 0.0037238	total: 635ms	remaining: 2.77s
# 56:	learn: 0.0034143	total: 646ms	remaining: 2.75s
# 57:	learn: 0.0032951	total: 657ms	remaining: 2.74s
# 58:	learn: 0.0030802	total: 668ms	remaining: 2.73s
# 59:	learn: 0.0029393	total: 680ms	remaining: 2.72s
# 60:	learn: 0.0027515	total: 692ms	remaining: 2.71s
# 61:	learn: 0.0026381	total: 703ms	remaining: 2.7s
# 62:	learn: 0.0025406	total: 715ms	remaining: 2.69s
# 63:	learn: 0.0024704	total: 727ms	remaining: 2.68s
# 64:	learn: 0.0024122	total: 738ms	remaining: 2.67s
# 65:	learn: 0.0023536	total: 750ms	remaining: 2.66s
# 66:	learn: 0.0023086	total: 762ms	remaining: 2.65s
# 67:	learn: 0.0023084	total: 772ms	remaining: 2.63s
# 68:	learn: 0.0022641	total: 783ms	remaining: 2.62s
# 69:	learn: 0.0021749	total: 794ms	remaining: 2.61s
# 70:	learn: 0.0021292	total: 806ms	remaining: 2.6s
# 71:	learn: 0.0020021	total: 817ms	remaining: 2.59s
# 72:	learn: 0.0018401	total: 828ms	remaining: 2.58s
# 73:	learn: 0.0017729	total: 840ms	remaining: 2.56s
# 74:	learn: 0.0017729	total: 850ms	remaining: 2.55s
# 75:	learn: 0.0016367	total: 861ms	remaining: 2.54s
# 76:	learn: 0.0015888	total: 873ms	remaining: 2.53s
# 77:	learn: 0.0015479	total: 884ms	remaining: 2.52s
# 78:	learn: 0.0015127	total: 895ms	remaining: 2.5s
# 79:	learn: 0.0015126	total: 905ms	remaining: 2.49s
# 80:	learn: 0.0014742	total: 917ms	remaining: 2.48s
# 81:	learn: 0.0014742	total: 926ms	remaining: 2.46s
# 82:	learn: 0.0014740	total: 936ms	remaining: 2.45s
# 83:	learn: 0.0014740	total: 946ms	remaining: 2.43s
# 84:	learn: 0.0014739	total: 956ms	remaining: 2.42s
# 85:	learn: 0.0014739	total: 966ms	remaining: 2.4s
# 86:	learn: 0.0014517	total: 977ms	remaining: 2.39s
# 87:	learn: 0.0014515	total: 987ms	remaining: 2.38s
# 88:	learn: 0.0014515	total: 997ms	remaining: 2.36s
# 89:	learn: 0.0014514	total: 1.01s	remaining: 2.35s
# 90:	learn: 0.0014118	total: 1.02s	remaining: 2.34s
# 91:	learn: 0.0014116	total: 1.03s	remaining: 2.32s
# 92:	learn: 0.0014116	total: 1.04s	remaining: 2.31s
# 93:	learn: 0.0014115	total: 1.05s	remaining: 2.3s
# 94:	learn: 0.0014115	total: 1.06s	remaining: 2.28s
# 95:	learn: 0.0014116	total: 1.07s	remaining: 2.27s
# 96:	learn: 0.0014115	total: 1.08s	remaining: 2.25s
# 97:	learn: 0.0013569	total: 1.09s	remaining: 2.24s
# 98:	learn: 0.0013275	total: 1.1s	remaining: 2.23s
# 99:	learn: 0.0013274	total: 1.11s	remaining: 2.22s
# 100:	learn: 0.0012863	total: 1.12s	remaining: 2.21s
# 101:	learn: 0.0012863	total: 1.13s	remaining: 2.19s
# 102:	learn: 0.0012863	total: 1.14s	remaining: 2.18s
# 103:	learn: 0.0012863	total: 1.15s	remaining: 2.17s
# 104:	learn: 0.0012863	total: 1.16s	remaining: 2.15s
# 105:	learn: 0.0012863	total: 1.17s	remaining: 2.14s
# 106:	learn: 0.0012863	total: 1.18s	remaining: 2.13s
# 107:	learn: 0.0012238	total: 1.19s	remaining: 2.12s
# 108:	learn: 0.0012237	total: 1.2s	remaining: 2.1s
# 109:	learn: 0.0012235	total: 1.21s	remaining: 2.09s
# 110:	learn: 0.0012235	total: 1.22s	remaining: 2.08s
# 111:	learn: 0.0012234	total: 1.23s	remaining: 2.07s
# 112:	learn: 0.0012234	total: 1.24s	remaining: 2.06s
# 113:	learn: 0.0012234	total: 1.25s	remaining: 2.04s
# 114:	learn: 0.0012233	total: 1.26s	remaining: 2.03s
# 115:	learn: 0.0012233	total: 1.27s	remaining: 2.02s
# 116:	learn: 0.0012232	total: 1.28s	remaining: 2s
# 117:	learn: 0.0012231	total: 1.29s	remaining: 1.99s
# 118:	learn: 0.0012230	total: 1.3s	remaining: 1.98s
# 119:	learn: 0.0012230	total: 1.31s	remaining: 1.97s
# 120:	learn: 0.0012230	total: 1.32s	remaining: 1.96s
# 121:	learn: 0.0012230	total: 1.33s	remaining: 1.94s
# 122:	learn: 0.0012230	total: 1.34s	remaining: 1.93s
# 123:	learn: 0.0012230	total: 1.35s	remaining: 1.92s
# 124:	learn: 0.0012230	total: 1.36s	remaining: 1.91s
# 125:	learn: 0.0012230	total: 1.37s	remaining: 1.89s
# 126:	learn: 0.0012230	total: 1.38s	remaining: 1.88s
# 127:	learn: 0.0012230	total: 1.39s	remaining: 1.87s
# 128:	learn: 0.0012230	total: 1.4s	remaining: 1.86s
# 129:	learn: 0.0012230	total: 1.41s	remaining: 1.84s
# 130:	learn: 0.0012230	total: 1.42s	remaining: 1.83s
# 131:	learn: 0.0012230	total: 1.43s	remaining: 1.82s
# 132:	learn: 0.0012230	total: 1.44s	remaining: 1.81s
# 133:	learn: 0.0012230	total: 1.45s	remaining: 1.79s
# 134:	learn: 0.0012230	total: 1.46s	remaining: 1.78s
# 135:	learn: 0.0012230	total: 1.47s	remaining: 1.77s
# 136:	learn: 0.0012230	total: 1.48s	remaining: 1.76s
# 137:	learn: 0.0012230	total: 1.49s	remaining: 1.75s
# 138:	learn: 0.0012230	total: 1.5s	remaining: 1.73s
# 139:	learn: 0.0012230	total: 1.51s	remaining: 1.72s
# 140:	learn: 0.0012230	total: 1.52s	remaining: 1.71s
# 141:	learn: 0.0012230	total: 1.53s	remaining: 1.7s
# 142:	learn: 0.0012230	total: 1.54s	remaining: 1.69s
# 143:	learn: 0.0012230	total: 1.55s	remaining: 1.68s
# 144:	learn: 0.0012230	total: 1.56s	remaining: 1.66s
# 145:	learn: 0.0012230	total: 1.57s	remaining: 1.65s
# 146:	learn: 0.0012230	total: 1.58s	remaining: 1.64s
# 147:	learn: 0.0012230	total: 1.59s	remaining: 1.63s
# 148:	learn: 0.0012230	total: 1.6s	remaining: 1.62s
# 149:	learn: 0.0012230	total: 1.6s	remaining: 1.6s
# 150:	learn: 0.0012230	total: 1.61s	remaining: 1.59s
# 151:	learn: 0.0012230	total: 1.63s	remaining: 1.58s
# 152:	learn: 0.0012230	total: 1.64s	remaining: 1.57s
# 153:	learn: 0.0012230	total: 1.65s	remaining: 1.56s
# 154:	learn: 0.0012230	total: 1.65s	remaining: 1.55s
# 155:	learn: 0.0012230	total: 1.66s	remaining: 1.54s
# 156:	learn: 0.0012230	total: 1.67s	remaining: 1.52s
# 157:	learn: 0.0012230	total: 1.68s	remaining: 1.51s
# 158:	learn: 0.0012230	total: 1.69s	remaining: 1.5s
# 159:	learn: 0.0012230	total: 1.7s	remaining: 1.49s
# 160:	learn: 0.0012230	total: 1.71s	remaining: 1.48s
# 161:	learn: 0.0012230	total: 1.72s	remaining: 1.47s
# 162:	learn: 0.0012230	total: 1.73s	remaining: 1.46s
# 163:	learn: 0.0012230	total: 1.74s	remaining: 1.44s
# 164:	learn: 0.0012230	total: 1.75s	remaining: 1.43s
# 165:	learn: 0.0012230	total: 1.76s	remaining: 1.42s
# 166:	learn: 0.0012230	total: 1.77s	remaining: 1.41s
# 167:	learn: 0.0012230	total: 1.78s	remaining: 1.4s
# 168:	learn: 0.0012230	total: 1.79s	remaining: 1.39s
# 169:	learn: 0.0012230	total: 1.8s	remaining: 1.38s
# 170:	learn: 0.0012230	total: 1.81s	remaining: 1.36s
# 171:	learn: 0.0012230	total: 1.82s	remaining: 1.35s
# 172:	learn: 0.0012230	total: 1.83s	remaining: 1.34s
# 173:	learn: 0.0012230	total: 1.84s	remaining: 1.33s
# 174:	learn: 0.0012230	total: 1.85s	remaining: 1.32s
# 175:	learn: 0.0012230	total: 1.86s	remaining: 1.31s
# 176:	learn: 0.0012230	total: 1.87s	remaining: 1.3s
# 177:	learn: 0.0012230	total: 1.88s	remaining: 1.29s
# 178:	learn: 0.0012230	total: 1.89s	remaining: 1.28s
# 179:	learn: 0.0012230	total: 1.9s	remaining: 1.26s
# 180:	learn: 0.0012230	total: 1.91s	remaining: 1.25s
# 181:	learn: 0.0012230	total: 1.92s	remaining: 1.24s
# 182:	learn: 0.0012230	total: 1.93s	remaining: 1.23s
# 183:	learn: 0.0012230	total: 1.94s	remaining: 1.22s
# 184:	learn: 0.0012230	total: 1.95s	remaining: 1.21s
# 185:	learn: 0.0012230	total: 1.96s	remaining: 1.2s
# 186:	learn: 0.0012230	total: 1.97s	remaining: 1.19s
# 187:	learn: 0.0012230	total: 1.98s	remaining: 1.18s
# 188:	learn: 0.0012230	total: 1.98s	remaining: 1.17s
# 189:	learn: 0.0012230	total: 2s	remaining: 1.16s
# 190:	learn: 0.0012230	total: 2s	remaining: 1.14s
# 191:	learn: 0.0012230	total: 2.01s	remaining: 1.13s
# 192:	learn: 0.0012230	total: 2.02s	remaining: 1.12s
# 193:	learn: 0.0012230	total: 2.03s	remaining: 1.11s
# 194:	learn: 0.0012230	total: 2.04s	remaining: 1.1s
# 195:	learn: 0.0012230	total: 2.05s	remaining: 1.09s
# 196:	learn: 0.0012230	total: 2.06s	remaining: 1.08s
# 197:	learn: 0.0012230	total: 2.07s	remaining: 1.07s
# 198:	learn: 0.0012230	total: 2.08s	remaining: 1.06s
# 199:	learn: 0.0012230	total: 2.09s	remaining: 1.05s
# 200:	learn: 0.0012230	total: 2.1s	remaining: 1.03s
# 201:	learn: 0.0012230	total: 2.11s	remaining: 1.02s
# 202:	learn: 0.0012230	total: 2.12s	remaining: 1.01s
# 203:	learn: 0.0012230	total: 2.13s	remaining: 1s
# 204:	learn: 0.0012230	total: 2.14s	remaining: 993ms
# 205:	learn: 0.0012230	total: 2.15s	remaining: 982ms
# 206:	learn: 0.0012230	total: 2.16s	remaining: 971ms
# 207:	learn: 0.0012230	total: 2.17s	remaining: 960ms
# 208:	learn: 0.0012230	total: 2.18s	remaining: 949ms
# 209:	learn: 0.0012230	total: 2.19s	remaining: 939ms
# 210:	learn: 0.0012230	total: 2.2s	remaining: 928ms
# 211:	learn: 0.0012230	total: 2.21s	remaining: 918ms
# 212:	learn: 0.0012230	total: 2.22s	remaining: 907ms
# 213:	learn: 0.0012230	total: 2.23s	remaining: 896ms
# 214:	learn: 0.0012230	total: 2.24s	remaining: 886ms
# 215:	learn: 0.0012230	total: 2.25s	remaining: 875ms
# 216:	learn: 0.0012230	total: 2.26s	remaining: 864ms
# 217:	learn: 0.0012230	total: 2.27s	remaining: 854ms
# 218:	learn: 0.0012230	total: 2.28s	remaining: 843ms
# 219:	learn: 0.0012230	total: 2.29s	remaining: 832ms
# 220:	learn: 0.0012230	total: 2.3s	remaining: 822ms
# 221:	learn: 0.0012230	total: 2.31s	remaining: 811ms
# 222:	learn: 0.0012230	total: 2.32s	remaining: 801ms
# 223:	learn: 0.0012230	total: 2.33s	remaining: 790ms
# 224:	learn: 0.0012230	total: 2.34s	remaining: 780ms
# 225:	learn: 0.0012230	total: 2.35s	remaining: 769ms
# 226:	learn: 0.0012230	total: 2.36s	remaining: 759ms
# 227:	learn: 0.0012230	total: 2.37s	remaining: 748ms
# 228:	learn: 0.0012230	total: 2.38s	remaining: 737ms
# 229:	learn: 0.0012230	total: 2.39s	remaining: 727ms
# 230:	learn: 0.0012230	total: 2.4s	remaining: 716ms
# 231:	learn: 0.0012230	total: 2.41s	remaining: 706ms
# 232:	learn: 0.0012230	total: 2.42s	remaining: 695ms
# 233:	learn: 0.0012230	total: 2.43s	remaining: 685ms
# 234:	learn: 0.0012230	total: 2.44s	remaining: 674ms
# 235:	learn: 0.0012230	total: 2.45s	remaining: 663ms
# 236:	learn: 0.0012230	total: 2.46s	remaining: 653ms
# 237:	learn: 0.0012230	total: 2.47s	remaining: 642ms
# 238:	learn: 0.0012230	total: 2.48s	remaining: 632ms
# 239:	learn: 0.0012230	total: 2.49s	remaining: 622ms
# 240:	learn: 0.0012230	total: 2.5s	remaining: 612ms
# 241:	learn: 0.0012230	total: 2.51s	remaining: 601ms
# 242:	learn: 0.0012230	total: 2.52s	remaining: 591ms
# 243:	learn: 0.0012230	total: 2.53s	remaining: 581ms
# 244:	learn: 0.0012230	total: 2.54s	remaining: 570ms
# 245:	learn: 0.0012230	total: 2.55s	remaining: 560ms
# 246:	learn: 0.0012230	total: 2.56s	remaining: 549ms
# 247:	learn: 0.0012230	total: 2.57s	remaining: 539ms
# 248:	learn: 0.0012230	total: 2.58s	remaining: 528ms
# 249:	learn: 0.0012230	total: 2.59s	remaining: 518ms
# 250:	learn: 0.0012230	total: 2.6s	remaining: 507ms
# 251:	learn: 0.0012230	total: 2.61s	remaining: 497ms
# 252:	learn: 0.0012230	total: 2.62s	remaining: 487ms
# 253:	learn: 0.0012230	total: 2.63s	remaining: 476ms
# 254:	learn: 0.0012230	total: 2.64s	remaining: 466ms
# 255:	learn: 0.0012230	total: 2.65s	remaining: 455ms
# 256:	learn: 0.0012230	total: 2.66s	remaining: 445ms
# 257:	learn: 0.0012230	total: 2.67s	remaining: 434ms
# 258:	learn: 0.0012230	total: 2.68s	remaining: 424ms
# 259:	learn: 0.0012230	total: 2.69s	remaining: 413ms
# 260:	learn: 0.0012230	total: 2.7s	remaining: 403ms
# 261:	learn: 0.0012230	total: 2.71s	remaining: 392ms
# 262:	learn: 0.0012230	total: 2.71s	remaining: 382ms
# 263:	learn: 0.0012230	total: 2.73s	remaining: 372ms
# 264:	learn: 0.0012230	total: 2.73s	remaining: 361ms
# 265:	learn: 0.0012230	total: 2.74s	remaining: 351ms
# 266:	learn: 0.0012230	total: 2.75s	remaining: 340ms
# 267:	learn: 0.0012230	total: 2.76s	remaining: 330ms
# 268:	learn: 0.0012230	total: 2.77s	remaining: 320ms
# 269:	learn: 0.0012230	total: 2.78s	remaining: 309ms
# 270:	learn: 0.0012230	total: 2.79s	remaining: 299ms
# 271:	learn: 0.0012230	total: 2.8s	remaining: 289ms
# 272:	learn: 0.0012230	total: 2.81s	remaining: 278ms
# 273:	learn: 0.0012230	total: 2.82s	remaining: 268ms
# 274:	learn: 0.0012230	total: 2.83s	remaining: 258ms
# 275:	learn: 0.0012230	total: 2.84s	remaining: 247ms
# 276:	learn: 0.0012230	total: 2.85s	remaining: 237ms
# 277:	learn: 0.0012230	total: 2.86s	remaining: 227ms
# 278:	learn: 0.0012230	total: 2.87s	remaining: 216ms
# 279:	learn: 0.0012230	total: 2.88s	remaining: 206ms
# 280:	learn: 0.0012230	total: 2.89s	remaining: 196ms
# 281:	learn: 0.0012230	total: 2.9s	remaining: 185ms
# 282:	learn: 0.0012230	total: 2.91s	remaining: 175ms
# 283:	learn: 0.0012230	total: 2.92s	remaining: 165ms
# 284:	learn: 0.0012230	total: 2.93s	remaining: 154ms
# 285:	learn: 0.0012230	total: 2.94s	remaining: 144ms
# 286:	learn: 0.0012230	total: 2.95s	remaining: 134ms
# 287:	learn: 0.0012230	total: 2.96s	remaining: 124ms
# 288:	learn: 0.0012230	total: 2.97s	remaining: 113ms
# 289:	learn: 0.0012230	total: 2.98s	remaining: 103ms
# 290:	learn: 0.0012230	total: 3s	remaining: 92.6ms
# 291:	learn: 0.0012230	total: 3s	remaining: 82.3ms
# 292:	learn: 0.0012230	total: 3.02s	remaining: 72.1ms
# 293:	learn: 0.0012230	total: 3.03s	remaining: 61.8ms
# 294:	learn: 0.0012230	total: 3.04s	remaining: 51.5ms
# 295:	learn: 0.0012230	total: 3.05s	remaining: 41.2ms
# 296:	learn: 0.0012230	total: 3.06s	remaining: 30.9ms
# 297:	learn: 0.0012230	total: 3.07s	remaining: 20.6ms
# 298:	learn: 0.0012230	total: 3.08s	remaining: 10.3ms
# 299:	learn: 0.0012230	total: 3.09s	remaining: 0us
# 0:	learn: 0.4176814	total: 11.4ms	remaining: 3.42s
# 1:	learn: 0.2828501	total: 21.4ms	remaining: 3.18s
# 2:	learn: 0.1885097	total: 32.5ms	remaining: 3.22s
# 3:	learn: 0.1483008	total: 43.5ms	remaining: 3.22s
# 4:	learn: 0.1204903	total: 54.2ms	remaining: 3.2s
# 5:	learn: 0.0963218	total: 65.2ms	remaining: 3.2s
# 6:	learn: 0.0849724	total: 75.8ms	remaining: 3.17s
# 7:	learn: 0.0777201	total: 86.8ms	remaining: 3.17s
# 8:	learn: 0.0691617	total: 98ms	remaining: 3.17s
# 9:	learn: 0.0621556	total: 109ms	remaining: 3.16s
# 10:	learn: 0.0588684	total: 120ms	remaining: 3.15s
# 11:	learn: 0.0535217	total: 132ms	remaining: 3.16s
# 12:	learn: 0.0510621	total: 143ms	remaining: 3.15s
# 13:	learn: 0.0484574	total: 154ms	remaining: 3.15s
# 14:	learn: 0.0445456	total: 165ms	remaining: 3.14s
# 15:	learn: 0.0430939	total: 176ms	remaining: 3.13s
# 16:	learn: 0.0413724	total: 188ms	remaining: 3.13s
# 17:	learn: 0.0382628	total: 199ms	remaining: 3.12s
# 18:	learn: 0.0345260	total: 211ms	remaining: 3.11s
# 19:	learn: 0.0325257	total: 222ms	remaining: 3.11s
# 20:	learn: 0.0290044	total: 234ms	remaining: 3.11s
# 21:	learn: 0.0277090	total: 245ms	remaining: 3.1s
# 22:	learn: 0.0255144	total: 256ms	remaining: 3.08s
# 23:	learn: 0.0231802	total: 267ms	remaining: 3.07s
# 24:	learn: 0.0201740	total: 278ms	remaining: 3.06s
# 25:	learn: 0.0187800	total: 289ms	remaining: 3.05s
# 26:	learn: 0.0179999	total: 301ms	remaining: 3.04s
# 27:	learn: 0.0172115	total: 312ms	remaining: 3.03s
# 28:	learn: 0.0164823	total: 323ms	remaining: 3.02s
# 29:	learn: 0.0154333	total: 334ms	remaining: 3s
# 30:	learn: 0.0140146	total: 345ms	remaining: 3s
# 31:	learn: 0.0134015	total: 356ms	remaining: 2.98s
# 32:	learn: 0.0123358	total: 367ms	remaining: 2.97s
# 33:	learn: 0.0117600	total: 378ms	remaining: 2.96s
# 34:	learn: 0.0109005	total: 389ms	remaining: 2.95s
# 35:	learn: 0.0102683	total: 400ms	remaining: 2.94s
# 36:	learn: 0.0095956	total: 411ms	remaining: 2.92s
# 37:	learn: 0.0087301	total: 422ms	remaining: 2.91s
# 38:	learn: 0.0082338	total: 433ms	remaining: 2.9s
# 39:	learn: 0.0076126	total: 444ms	remaining: 2.89s
# 40:	learn: 0.0072960	total: 455ms	remaining: 2.88s
# 41:	learn: 0.0068880	total: 467ms	remaining: 2.87s
# 42:	learn: 0.0062982	total: 478ms	remaining: 2.86s
# 43:	learn: 0.0060662	total: 490ms	remaining: 2.85s
# 44:	learn: 0.0058627	total: 501ms	remaining: 2.84s
# 45:	learn: 0.0056077	total: 512ms	remaining: 2.83s
# 46:	learn: 0.0052569	total: 524ms	remaining: 2.82s
# 47:	learn: 0.0048680	total: 535ms	remaining: 2.81s
# 48:	learn: 0.0046384	total: 546ms	remaining: 2.8s
# 49:	learn: 0.0045199	total: 558ms	remaining: 2.79s
# 50:	learn: 0.0043901	total: 570ms	remaining: 2.78s
# 51:	learn: 0.0043322	total: 581ms	remaining: 2.77s
# 52:	learn: 0.0042019	total: 593ms	remaining: 2.76s
# 53:	learn: 0.0041266	total: 604ms	remaining: 2.75s
# 54:	learn: 0.0040337	total: 615ms	remaining: 2.74s
# 55:	learn: 0.0039160	total: 626ms	remaining: 2.73s
# 56:	learn: 0.0036833	total: 637ms	remaining: 2.71s
# 57:	learn: 0.0033994	total: 648ms	remaining: 2.7s
# 58:	learn: 0.0031191	total: 659ms	remaining: 2.69s
# 59:	learn: 0.0030365	total: 670ms	remaining: 2.68s
# 60:	learn: 0.0029775	total: 681ms	remaining: 2.67s
# 61:	learn: 0.0029776	total: 690ms	remaining: 2.65s
# 62:	learn: 0.0029214	total: 702ms	remaining: 2.64s
# 63:	learn: 0.0027652	total: 713ms	remaining: 2.63s
# 64:	learn: 0.0026322	total: 724ms	remaining: 2.62s
# 65:	learn: 0.0025823	total: 736ms	remaining: 2.61s
# 66:	learn: 0.0025059	total: 747ms	remaining: 2.6s
# 67:	learn: 0.0025059	total: 756ms	remaining: 2.58s
# 68:	learn: 0.0024301	total: 767ms	remaining: 2.57s
# 69:	learn: 0.0023725	total: 778ms	remaining: 2.56s
# 70:	learn: 0.0022726	total: 790ms	remaining: 2.55s
# 71:	learn: 0.0021479	total: 801ms	remaining: 2.54s
# 72:	learn: 0.0020882	total: 812ms	remaining: 2.52s
# 73:	learn: 0.0019875	total: 823ms	remaining: 2.51s
# 74:	learn: 0.0019457	total: 835ms	remaining: 2.5s
# 75:	learn: 0.0018604	total: 846ms	remaining: 2.49s
# 76:	learn: 0.0017942	total: 858ms	remaining: 2.48s
# 77:	learn: 0.0017942	total: 867ms	remaining: 2.47s
# 78:	learn: 0.0017176	total: 879ms	remaining: 2.46s
# 79:	learn: 0.0017176	total: 889ms	remaining: 2.44s
# 80:	learn: 0.0017176	total: 899ms	remaining: 2.43s
# 81:	learn: 0.0016681	total: 910ms	remaining: 2.42s
# 82:	learn: 0.0016681	total: 920ms	remaining: 2.41s
# 83:	learn: 0.0016680	total: 930ms	remaining: 2.39s
# 84:	learn: 0.0016680	total: 940ms	remaining: 2.38s
# 85:	learn: 0.0016301	total: 950ms	remaining: 2.37s
# 86:	learn: 0.0015972	total: 962ms	remaining: 2.35s
# 87:	learn: 0.0015547	total: 973ms	remaining: 2.34s
# 88:	learn: 0.0015547	total: 983ms	remaining: 2.33s
# 89:	learn: 0.0015547	total: 992ms	remaining: 2.31s
# 90:	learn: 0.0015090	total: 1s	remaining: 2.3s
# 91:	learn: 0.0015090	total: 1.01s	remaining: 2.29s
# 92:	learn: 0.0015090	total: 1.02s	remaining: 2.28s
# 93:	learn: 0.0015090	total: 1.03s	remaining: 2.26s
# 94:	learn: 0.0015090	total: 1.04s	remaining: 2.25s
# 95:	learn: 0.0014468	total: 1.05s	remaining: 2.24s
# 96:	learn: 0.0014468	total: 1.06s	remaining: 2.23s
# 97:	learn: 0.0014032	total: 1.07s	remaining: 2.21s
# 98:	learn: 0.0014032	total: 1.08s	remaining: 2.2s
# 99:	learn: 0.0013604	total: 1.1s	remaining: 2.19s
# 100:	learn: 0.0013603	total: 1.11s	remaining: 2.18s
# 101:	learn: 0.0013603	total: 1.11s	remaining: 2.17s
# 102:	learn: 0.0013603	total: 1.13s	remaining: 2.15s
# 103:	learn: 0.0013603	total: 1.14s	remaining: 2.14s
# 104:	learn: 0.0013603	total: 1.15s	remaining: 2.13s
# 105:	learn: 0.0013603	total: 1.16s	remaining: 2.11s
# 106:	learn: 0.0013602	total: 1.17s	remaining: 2.1s
# 107:	learn: 0.0013602	total: 1.17s	remaining: 2.09s
# 108:	learn: 0.0013602	total: 1.19s	remaining: 2.08s
# 109:	learn: 0.0013602	total: 1.2s	remaining: 2.06s
# 110:	learn: 0.0013601	total: 1.21s	remaining: 2.05s
# 111:	learn: 0.0013601	total: 1.22s	remaining: 2.04s
# 112:	learn: 0.0013601	total: 1.23s	remaining: 2.03s
# 113:	learn: 0.0013600	total: 1.24s	remaining: 2.02s
# 114:	learn: 0.0013600	total: 1.25s	remaining: 2s
# 115:	learn: 0.0013599	total: 1.25s	remaining: 1.99s
# 116:	learn: 0.0013330	total: 1.27s	remaining: 1.98s
# 117:	learn: 0.0013330	total: 1.28s	remaining: 1.97s
# 118:	learn: 0.0012503	total: 1.29s	remaining: 1.96s
# 119:	learn: 0.0012503	total: 1.3s	remaining: 1.95s
# 120:	learn: 0.0012504	total: 1.31s	remaining: 1.93s
# 121:	learn: 0.0012503	total: 1.32s	remaining: 1.92s
# 122:	learn: 0.0012503	total: 1.33s	remaining: 1.91s
# 123:	learn: 0.0012503	total: 1.34s	remaining: 1.9s
# 124:	learn: 0.0012503	total: 1.34s	remaining: 1.88s
# 125:	learn: 0.0012503	total: 1.35s	remaining: 1.87s
# 126:	learn: 0.0012502	total: 1.36s	remaining: 1.86s
# 127:	learn: 0.0012502	total: 1.37s	remaining: 1.85s
# 128:	learn: 0.0012501	total: 1.38s	remaining: 1.83s
# 129:	learn: 0.0012501	total: 1.39s	remaining: 1.82s
# 130:	learn: 0.0012501	total: 1.4s	remaining: 1.81s
# 131:	learn: 0.0012500	total: 1.41s	remaining: 1.8s
# 132:	learn: 0.0012500	total: 1.42s	remaining: 1.79s
# 133:	learn: 0.0012501	total: 1.43s	remaining: 1.77s
# 134:	learn: 0.0012500	total: 1.44s	remaining: 1.76s
# 135:	learn: 0.0012500	total: 1.45s	remaining: 1.75s
# 136:	learn: 0.0012500	total: 1.46s	remaining: 1.74s
# 137:	learn: 0.0012500	total: 1.47s	remaining: 1.73s
# 138:	learn: 0.0012500	total: 1.48s	remaining: 1.72s
# 139:	learn: 0.0012499	total: 1.49s	remaining: 1.7s
# 140:	learn: 0.0012500	total: 1.5s	remaining: 1.69s
# 141:	learn: 0.0012499	total: 1.51s	remaining: 1.68s
# 142:	learn: 0.0012499	total: 1.52s	remaining: 1.67s
# 143:	learn: 0.0012499	total: 1.53s	remaining: 1.66s
# 144:	learn: 0.0012498	total: 1.54s	remaining: 1.65s
# 145:	learn: 0.0012498	total: 1.55s	remaining: 1.63s
# 146:	learn: 0.0012498	total: 1.56s	remaining: 1.62s
# 147:	learn: 0.0012498	total: 1.57s	remaining: 1.61s
# 148:	learn: 0.0012498	total: 1.58s	remaining: 1.6s
# 149:	learn: 0.0012498	total: 1.59s	remaining: 1.59s
# 150:	learn: 0.0012498	total: 1.6s	remaining: 1.58s
# 151:	learn: 0.0012498	total: 1.61s	remaining: 1.56s
# 152:	learn: 0.0012497	total: 1.62s	remaining: 1.55s
# 153:	learn: 0.0012498	total: 1.63s	remaining: 1.54s
# 154:	learn: 0.0012497	total: 1.64s	remaining: 1.53s
# 155:	learn: 0.0012497	total: 1.65s	remaining: 1.52s
# 156:	learn: 0.0012497	total: 1.65s	remaining: 1.51s
# 157:	learn: 0.0012497	total: 1.66s	remaining: 1.5s
# 158:	learn: 0.0012497	total: 1.67s	remaining: 1.48s
# 159:	learn: 0.0012497	total: 1.68s	remaining: 1.47s
# 160:	learn: 0.0012497	total: 1.69s	remaining: 1.46s
# 161:	learn: 0.0012497	total: 1.7s	remaining: 1.45s
# 162:	learn: 0.0012497	total: 1.71s	remaining: 1.44s
# 163:	learn: 0.0012497	total: 1.72s	remaining: 1.43s
# 164:	learn: 0.0012497	total: 1.73s	remaining: 1.42s
# 165:	learn: 0.0012497	total: 1.74s	remaining: 1.41s
# 166:	learn: 0.0012497	total: 1.75s	remaining: 1.39s
# 167:	learn: 0.0012497	total: 1.76s	remaining: 1.38s
# 168:	learn: 0.0012497	total: 1.77s	remaining: 1.37s
# 169:	learn: 0.0012497	total: 1.78s	remaining: 1.36s
# 170:	learn: 0.0012497	total: 1.79s	remaining: 1.35s
# 171:	learn: 0.0012497	total: 1.8s	remaining: 1.34s
# 172:	learn: 0.0012497	total: 1.81s	remaining: 1.33s
# 173:	learn: 0.0012497	total: 1.82s	remaining: 1.32s
# 174:	learn: 0.0012497	total: 1.83s	remaining: 1.3s
# 175:	learn: 0.0012497	total: 1.84s	remaining: 1.29s
# 176:	learn: 0.0012497	total: 1.85s	remaining: 1.28s
# 177:	learn: 0.0012497	total: 1.85s	remaining: 1.27s
# 178:	learn: 0.0012497	total: 1.86s	remaining: 1.26s
# 179:	learn: 0.0012497	total: 1.87s	remaining: 1.25s
# 180:	learn: 0.0012497	total: 1.88s	remaining: 1.24s
# 181:	learn: 0.0012497	total: 1.89s	remaining: 1.23s
# 182:	learn: 0.0012497	total: 1.9s	remaining: 1.22s
# 183:	learn: 0.0012497	total: 1.91s	remaining: 1.21s
# 184:	learn: 0.0012497	total: 1.92s	remaining: 1.2s
# 185:	learn: 0.0012497	total: 1.93s	remaining: 1.18s
# 186:	learn: 0.0012497	total: 1.94s	remaining: 1.17s
# 187:	learn: 0.0012497	total: 1.95s	remaining: 1.16s
# 188:	learn: 0.0012497	total: 1.96s	remaining: 1.15s
# 189:	learn: 0.0012497	total: 1.97s	remaining: 1.14s
# 190:	learn: 0.0012497	total: 1.98s	remaining: 1.13s
# 191:	learn: 0.0012497	total: 1.99s	remaining: 1.12s
# 192:	learn: 0.0012497	total: 2s	remaining: 1.11s
# 193:	learn: 0.0012497	total: 2.01s	remaining: 1.1s
# 194:	learn: 0.0012497	total: 2.02s	remaining: 1.09s
# 195:	learn: 0.0012497	total: 2.03s	remaining: 1.07s
# 196:	learn: 0.0012497	total: 2.04s	remaining: 1.06s
# 197:	learn: 0.0012497	total: 2.04s	remaining: 1.05s
# 198:	learn: 0.0012497	total: 2.05s	remaining: 1.04s
# 199:	learn: 0.0012497	total: 2.06s	remaining: 1.03s
# 200:	learn: 0.0012497	total: 2.07s	remaining: 1.02s
# 201:	learn: 0.0012497	total: 2.08s	remaining: 1.01s
# 202:	learn: 0.0012497	total: 2.09s	remaining: 1s
# 203:	learn: 0.0012497	total: 2.1s	remaining: 989ms
# 204:	learn: 0.0012497	total: 2.11s	remaining: 979ms
# 205:	learn: 0.0012497	total: 2.12s	remaining: 968ms
# 206:	learn: 0.0012497	total: 2.13s	remaining: 958ms
# 207:	learn: 0.0012497	total: 2.14s	remaining: 947ms
# 208:	learn: 0.0012497	total: 2.15s	remaining: 936ms
# 209:	learn: 0.0012497	total: 2.16s	remaining: 926ms
# 210:	learn: 0.0012497	total: 2.17s	remaining: 915ms
# 211:	learn: 0.0012497	total: 2.18s	remaining: 905ms
# 212:	learn: 0.0012497	total: 2.19s	remaining: 894ms
# 213:	learn: 0.0012497	total: 2.2s	remaining: 883ms
# 214:	learn: 0.0012497	total: 2.21s	remaining: 873ms
# 215:	learn: 0.0012497	total: 2.22s	remaining: 862ms
# 216:	learn: 0.0012497	total: 2.23s	remaining: 852ms
# 217:	learn: 0.0012497	total: 2.23s	remaining: 841ms
# 218:	learn: 0.0012497	total: 2.25s	remaining: 830ms
# 219:	learn: 0.0012497	total: 2.25s	remaining: 820ms
# 220:	learn: 0.0012497	total: 2.26s	remaining: 809ms
# 221:	learn: 0.0012497	total: 2.27s	remaining: 799ms
# 222:	learn: 0.0012497	total: 2.28s	remaining: 788ms
# 223:	learn: 0.0012497	total: 2.29s	remaining: 778ms
# 224:	learn: 0.0012497	total: 2.3s	remaining: 767ms
# 225:	learn: 0.0012497	total: 2.31s	remaining: 757ms
# 226:	learn: 0.0012497	total: 2.32s	remaining: 747ms
# 227:	learn: 0.0012497	total: 2.33s	remaining: 736ms
# 228:	learn: 0.0012497	total: 2.34s	remaining: 726ms
# 229:	learn: 0.0012497	total: 2.35s	remaining: 715ms
# 230:	learn: 0.0012497	total: 2.36s	remaining: 705ms
# 231:	learn: 0.0012497	total: 2.37s	remaining: 695ms
# 232:	learn: 0.0012497	total: 2.38s	remaining: 684ms
# 233:	learn: 0.0012497	total: 2.39s	remaining: 674ms
# 234:	learn: 0.0012497	total: 2.4s	remaining: 663ms
# 235:	learn: 0.0012497	total: 2.41s	remaining: 653ms
# 236:	learn: 0.0012497	total: 2.42s	remaining: 643ms
# 237:	learn: 0.0012497	total: 2.43s	remaining: 632ms
# 238:	learn: 0.0012497	total: 2.44s	remaining: 622ms
# 239:	learn: 0.0012497	total: 2.45s	remaining: 612ms
# 240:	learn: 0.0012497	total: 2.46s	remaining: 601ms
# 241:	learn: 0.0012497	total: 2.46s	remaining: 591ms
# 242:	learn: 0.0012497	total: 2.48s	remaining: 581ms
# 243:	learn: 0.0012497	total: 2.48s	remaining: 570ms
# 244:	learn: 0.0012497	total: 2.49s	remaining: 560ms
# 245:	learn: 0.0012497	total: 2.5s	remaining: 550ms
# 246:	learn: 0.0012497	total: 2.51s	remaining: 540ms
# 247:	learn: 0.0012497	total: 2.52s	remaining: 529ms
# 248:	learn: 0.0012497	total: 2.53s	remaining: 519ms
# 249:	learn: 0.0012497	total: 2.54s	remaining: 509ms
# 250:	learn: 0.0012497	total: 2.55s	remaining: 499ms
# 251:	learn: 0.0012497	total: 2.56s	remaining: 488ms
# 252:	learn: 0.0012497	total: 2.57s	remaining: 478ms
# 253:	learn: 0.0012497	total: 2.58s	remaining: 468ms
# 254:	learn: 0.0012497	total: 2.59s	remaining: 458ms
# 255:	learn: 0.0012497	total: 2.6s	remaining: 447ms
# 256:	learn: 0.0012497	total: 2.61s	remaining: 437ms
# 257:	learn: 0.0012497	total: 2.62s	remaining: 427ms
# 258:	learn: 0.0012497	total: 2.63s	remaining: 417ms
# 259:	learn: 0.0012497	total: 2.64s	remaining: 406ms
# 260:	learn: 0.0012497	total: 2.65s	remaining: 396ms
# 261:	learn: 0.0012497	total: 2.66s	remaining: 386ms
# 262:	learn: 0.0012497	total: 2.67s	remaining: 376ms
# 263:	learn: 0.0012497	total: 2.68s	remaining: 365ms
# 264:	learn: 0.0012497	total: 2.69s	remaining: 355ms
# 265:	learn: 0.0012497	total: 2.7s	remaining: 345ms
# 266:	learn: 0.0012497	total: 2.71s	remaining: 335ms
# 267:	learn: 0.0012497	total: 2.72s	remaining: 324ms
# 268:	learn: 0.0012497	total: 2.73s	remaining: 314ms
# 269:	learn: 0.0012497	total: 2.74s	remaining: 304ms
# 270:	learn: 0.0012497	total: 2.75s	remaining: 294ms
# 271:	learn: 0.0012497	total: 2.75s	remaining: 284ms
# 272:	learn: 0.0012497	total: 2.76s	remaining: 273ms
# 273:	learn: 0.0012497	total: 2.77s	remaining: 263ms
# 274:	learn: 0.0012497	total: 2.78s	remaining: 253ms
# 275:	learn: 0.0012497	total: 2.79s	remaining: 243ms
# 276:	learn: 0.0012497	total: 2.8s	remaining: 233ms
# 277:	learn: 0.0012497	total: 2.81s	remaining: 223ms
# 278:	learn: 0.0012497	total: 2.82s	remaining: 212ms
# 279:	learn: 0.0012497	total: 2.83s	remaining: 202ms
# 280:	learn: 0.0012497	total: 2.84s	remaining: 192ms
# 281:	learn: 0.0012497	total: 2.85s	remaining: 182ms
# 282:	learn: 0.0012497	total: 2.86s	remaining: 172ms
# 283:	learn: 0.0012497	total: 2.87s	remaining: 162ms
# 284:	learn: 0.0012497	total: 2.88s	remaining: 151ms
# 285:	learn: 0.0012497	total: 2.89s	remaining: 141ms
# 286:	learn: 0.0012497	total: 2.9s	remaining: 131ms
# 287:	learn: 0.0012497	total: 2.91s	remaining: 121ms
# 288:	learn: 0.0012497	total: 2.92s	remaining: 111ms
# 289:	learn: 0.0012497	total: 2.93s	remaining: 101ms
# 290:	learn: 0.0012497	total: 2.94s	remaining: 91ms
# 291:	learn: 0.0012497	total: 2.95s	remaining: 80.9ms
# 292:	learn: 0.0012497	total: 2.96s	remaining: 70.8ms
# 293:	learn: 0.0012497	total: 2.97s	remaining: 60.6ms
# 294:	learn: 0.0012497	total: 2.98s	remaining: 50.5ms
# 295:	learn: 0.0012497	total: 2.99s	remaining: 40.4ms
# 296:	learn: 0.0012497	total: 3s	remaining: 30.3ms
# 297:	learn: 0.0012497	total: 3.01s	remaining: 20.2ms
# 298:	learn: 0.0012497	total: 3.02s	remaining: 10.1ms
# 299:	learn: 0.0012497	total: 3.03s	remaining: 0us
# 0:	learn: 0.4168386	total: 11.6ms	remaining: 3.47s
# ...
# 291:	learn: 0.0011575	total: 2.99s	remaining: 81.8ms
# 292:	learn: 0.0011575	total: 3s	remaining: 71.6ms
# 293:	learn: 0.0011575	total: 3.01s	remaining: 61.4ms
# 294:	learn: 0.0011575	total: 3.02s	remaining: 51.1ms
# 295:	learn: 0.0011575	total: 3.03s	remaining: 40.9ms
# 296:	learn: 0.0011575	total: 3.04s	remaining: 30.7ms
# 297:	learn: 0.0011575	total: 3.05s	remaining: 20.4ms
# 298:	learn: 0.0011575	total: 3.06s	remaining: 10.2ms
# 299:	learn: 0.0011575	total: 3.07s	remaining: 0us
# 0:	learn: 0.4238249	total: 11.1ms	remaining: 3.32s
# 1:	learn: 0.2640851	total: 21.4ms	remaining: 3.19s
# 2:	learn: 0.1932813	total: 32.8ms	remaining: 3.25s
# 3:	learn: 0.1382224	total: 43.6ms	remaining: 3.23s
# 4:	learn: 0.1099696	total: 54.4ms	remaining: 3.21s
# 5:	learn: 0.0959654	total: 65.2ms	remaining: 3.19s
# 6:	learn: 0.0804279	total: 76.3ms	remaining: 3.19s
# 7:	learn: 0.0699831	total: 87.1ms	remaining: 3.18s
# 8:	learn: 0.0658874	total: 97.8ms	remaining: 3.16s
# 9:	learn: 0.0575406	total: 109ms	remaining: 3.15s
# 10:	learn: 0.0527394	total: 119ms	remaining: 3.14s
# 11:	learn: 0.0499978	total: 131ms	remaining: 3.13s
# 12:	learn: 0.0450377	total: 141ms	remaining: 3.12s
# 13:	learn: 0.0429118	total: 152ms	remaining: 3.11s
# 14:	learn: 0.0386431	total: 164ms	remaining: 3.11s
# 15:	learn: 0.0359936	total: 175ms	remaining: 3.11s
# 16:	learn: 0.0341454	total: 186ms	remaining: 3.1s
# 17:	learn: 0.0315374	total: 197ms	remaining: 3.09s
# 18:	learn: 0.0290654	total: 209ms	remaining: 3.09s
# 19:	learn: 0.0265886	total: 221ms	remaining: 3.09s
# 20:	learn: 0.0252296	total: 232ms	remaining: 3.09s
# 21:	learn: 0.0238305	total: 243ms	remaining: 3.08s
# 22:	learn: 0.0217967	total: 255ms	remaining: 3.07s
# 23:	learn: 0.0207709	total: 266ms	remaining: 3.06s
# 24:	learn: 0.0199000	total: 277ms	remaining: 3.05s
# 25:	learn: 0.0186880	total: 288ms	remaining: 3.04s
# 26:	learn: 0.0167823	total: 299ms	remaining: 3.02s
# 27:	learn: 0.0160194	total: 311ms	remaining: 3.02s
# 28:	learn: 0.0153271	total: 322ms	remaining: 3.01s
# 29:	learn: 0.0140980	total: 333ms	remaining: 3s
# 30:	learn: 0.0136523	total: 344ms	remaining: 2.98s
# 31:	learn: 0.0133509	total: 354ms	remaining: 2.96s
# 32:	learn: 0.0118896	total: 365ms	remaining: 2.96s
# 33:	learn: 0.0116423	total: 377ms	remaining: 2.95s
# 34:	learn: 0.0109637	total: 388ms	remaining: 2.94s
# 35:	learn: 0.0105020	total: 399ms	remaining: 2.92s
# 36:	learn: 0.0102237	total: 410ms	remaining: 2.91s
# 37:	learn: 0.0092745	total: 421ms	remaining: 2.9s
# 38:	learn: 0.0086800	total: 432ms	remaining: 2.89s
# 39:	learn: 0.0082429	total: 443ms	remaining: 2.88s
# 40:	learn: 0.0074676	total: 455ms	remaining: 2.87s
# 41:	learn: 0.0068473	total: 466ms	remaining: 2.86s
# 42:	learn: 0.0066416	total: 476ms	remaining: 2.85s
# 43:	learn: 0.0063413	total: 487ms	remaining: 2.83s
# 44:	learn: 0.0059861	total: 498ms	remaining: 2.82s
# 45:	learn: 0.0058515	total: 509ms	remaining: 2.81s
# 46:	learn: 0.0056734	total: 520ms	remaining: 2.8s
# 47:	learn: 0.0055040	total: 531ms	remaining: 2.79s
# 48:	learn: 0.0051358	total: 542ms	remaining: 2.77s
# 49:	learn: 0.0049825	total: 552ms	remaining: 2.76s
# 50:	learn: 0.0048880	total: 563ms	remaining: 2.75s
# 51:	learn: 0.0046069	total: 574ms	remaining: 2.74s
# 52:	learn: 0.0044413	total: 586ms	remaining: 2.73s
# 53:	learn: 0.0040657	total: 597ms	remaining: 2.72s
# 54:	learn: 0.0039237	total: 608ms	remaining: 2.71s
# 55:	learn: 0.0038622	total: 619ms	remaining: 2.7s
# 56:	learn: 0.0038003	total: 630ms	remaining: 2.69s
# 57:	learn: 0.0035818	total: 641ms	remaining: 2.67s
# 58:	learn: 0.0034857	total: 652ms	remaining: 2.66s
# 59:	learn: 0.0034506	total: 663ms	remaining: 2.65s
# 60:	learn: 0.0034023	total: 674ms	remaining: 2.64s
# 61:	learn: 0.0033039	total: 685ms	remaining: 2.63s
# 62:	learn: 0.0032370	total: 695ms	remaining: 2.62s
# 63:	learn: 0.0030907	total: 706ms	remaining: 2.6s
# 64:	learn: 0.0029412	total: 718ms	remaining: 2.59s
# 65:	learn: 0.0026544	total: 729ms	remaining: 2.58s
# 66:	learn: 0.0026031	total: 739ms	remaining: 2.57s
# 67:	learn: 0.0025734	total: 751ms	remaining: 2.56s
# 68:	learn: 0.0024790	total: 761ms	remaining: 2.55s
# 69:	learn: 0.0023296	total: 772ms	remaining: 2.54s
# 70:	learn: 0.0022655	total: 784ms	remaining: 2.53s
# 71:	learn: 0.0021319	total: 795ms	remaining: 2.52s
# 72:	learn: 0.0021319	total: 804ms	remaining: 2.5s
# 73:	learn: 0.0021319	total: 814ms	remaining: 2.48s
# 74:	learn: 0.0019785	total: 825ms	remaining: 2.47s
# 75:	learn: 0.0019785	total: 834ms	remaining: 2.46s
# 76:	learn: 0.0018837	total: 845ms	remaining: 2.45s
# 77:	learn: 0.0018471	total: 856ms	remaining: 2.44s
# 78:	learn: 0.0018035	total: 867ms	remaining: 2.42s
# 79:	learn: 0.0017540	total: 878ms	remaining: 2.42s
# 80:	learn: 0.0016988	total: 889ms	remaining: 2.4s
# 81:	learn: 0.0016988	total: 899ms	remaining: 2.39s
# 82:	learn: 0.0016989	total: 909ms	remaining: 2.38s
# 83:	learn: 0.0016988	total: 918ms	remaining: 2.36s
# 84:	learn: 0.0016987	total: 927ms	remaining: 2.35s
# 85:	learn: 0.0016987	total: 937ms	remaining: 2.33s
# 86:	learn: 0.0016988	total: 947ms	remaining: 2.32s
# 87:	learn: 0.0016987	total: 957ms	remaining: 2.3s
# 88:	learn: 0.0016987	total: 966ms	remaining: 2.29s
# 89:	learn: 0.0016986	total: 976ms	remaining: 2.28s
# 90:	learn: 0.0016986	total: 986ms	remaining: 2.26s
# 91:	learn: 0.0016593	total: 997ms	remaining: 2.25s
# 92:	learn: 0.0016593	total: 1.01s	remaining: 2.24s
# 93:	learn: 0.0016593	total: 1.01s	remaining: 2.23s
# 94:	learn: 0.0016593	total: 1.02s	remaining: 2.21s
# 95:	learn: 0.0016050	total: 1.04s	remaining: 2.2s
# 96:	learn: 0.0015535	total: 1.05s	remaining: 2.19s
# 97:	learn: 0.0015535	total: 1.06s	remaining: 2.18s
# 98:	learn: 0.0015196	total: 1.07s	remaining: 2.17s
# 99:	learn: 0.0014615	total: 1.08s	remaining: 2.16s
# 100:	learn: 0.0013917	total: 1.09s	remaining: 2.15s
# 101:	learn: 0.0013321	total: 1.1s	remaining: 2.14s
# 102:	learn: 0.0013319	total: 1.11s	remaining: 2.13s
# 103:	learn: 0.0013319	total: 1.12s	remaining: 2.11s
# 104:	learn: 0.0013319	total: 1.13s	remaining: 2.1s
# 105:	learn: 0.0013319	total: 1.14s	remaining: 2.08s
# 106:	learn: 0.0013318	total: 1.15s	remaining: 2.07s
# 107:	learn: 0.0012693	total: 1.16s	remaining: 2.06s
# 108:	learn: 0.0012693	total: 1.17s	remaining: 2.05s
# 109:	learn: 0.0012693	total: 1.18s	remaining: 2.04s
# 110:	learn: 0.0012155	total: 1.19s	remaining: 2.03s
# 111:	learn: 0.0012154	total: 1.2s	remaining: 2.01s
# 112:	learn: 0.0012154	total: 1.21s	remaining: 2s
# 113:	learn: 0.0012154	total: 1.22s	remaining: 1.99s
# 114:	learn: 0.0011755	total: 1.23s	remaining: 1.98s
# 115:	learn: 0.0011755	total: 1.24s	remaining: 1.97s
# 116:	learn: 0.0011755	total: 1.25s	remaining: 1.96s
# 117:	learn: 0.0011754	total: 1.26s	remaining: 1.94s
# 118:	learn: 0.0011754	total: 1.27s	remaining: 1.93s
# 119:	learn: 0.0011753	total: 1.28s	remaining: 1.92s
# 120:	learn: 0.0011287	total: 1.29s	remaining: 1.91s
# 121:	learn: 0.0011286	total: 1.3s	remaining: 1.9s
# 122:	learn: 0.0011286	total: 1.31s	remaining: 1.88s
# 123:	learn: 0.0011286	total: 1.32s	remaining: 1.87s
# 124:	learn: 0.0011028	total: 1.33s	remaining: 1.86s
# 125:	learn: 0.0010585	total: 1.34s	remaining: 1.85s
# 126:	learn: 0.0010501	total: 1.35s	remaining: 1.84s
# 127:	learn: 0.0010501	total: 1.36s	remaining: 1.83s
# 128:	learn: 0.0010500	total: 1.37s	remaining: 1.81s
# 129:	learn: 0.0010027	total: 1.38s	remaining: 1.8s
# 130:	learn: 0.0009701	total: 1.39s	remaining: 1.79s
# 131:	learn: 0.0009700	total: 1.4s	remaining: 1.78s
# 132:	learn: 0.0009701	total: 1.41s	remaining: 1.77s
# 133:	learn: 0.0009700	total: 1.42s	remaining: 1.76s
# 134:	learn: 0.0009701	total: 1.43s	remaining: 1.75s
# 135:	learn: 0.0009700	total: 1.44s	remaining: 1.74s
# 136:	learn: 0.0009700	total: 1.45s	remaining: 1.72s
# 137:	learn: 0.0009699	total: 1.46s	remaining: 1.71s
# 138:	learn: 0.0009698	total: 1.47s	remaining: 1.7s
# 139:	learn: 0.0009698	total: 1.48s	remaining: 1.69s
# 140:	learn: 0.0009698	total: 1.49s	remaining: 1.68s
# 141:	learn: 0.0009697	total: 1.5s	remaining: 1.67s
# 142:	learn: 0.0009697	total: 1.51s	remaining: 1.66s
# 143:	learn: 0.0009697	total: 1.52s	remaining: 1.64s
# 144:	learn: 0.0009697	total: 1.53s	remaining: 1.63s
# 145:	learn: 0.0009697	total: 1.54s	remaining: 1.62s
# 146:	learn: 0.0009697	total: 1.55s	remaining: 1.61s
# 147:	learn: 0.0009697	total: 1.56s	remaining: 1.6s
# 148:	learn: 0.0009696	total: 1.57s	remaining: 1.59s
# 149:	learn: 0.0009696	total: 1.58s	remaining: 1.58s
# 150:	learn: 0.0009696	total: 1.59s	remaining: 1.56s
# 151:	learn: 0.0009695	total: 1.59s	remaining: 1.55s
# 152:	learn: 0.0009695	total: 1.6s	remaining: 1.54s
# 153:	learn: 0.0009695	total: 1.61s	remaining: 1.53s
# 154:	learn: 0.0009696	total: 1.62s	remaining: 1.52s
# 155:	learn: 0.0009695	total: 1.63s	remaining: 1.51s
# 156:	learn: 0.0009695	total: 1.64s	remaining: 1.5s
# 157:	learn: 0.0009695	total: 1.65s	remaining: 1.49s
# 158:	learn: 0.0009695	total: 1.66s	remaining: 1.47s
# 159:	learn: 0.0009695	total: 1.67s	remaining: 1.46s
# 160:	learn: 0.0009695	total: 1.68s	remaining: 1.45s
# 161:	learn: 0.0009695	total: 1.69s	remaining: 1.44s
# 162:	learn: 0.0009695	total: 1.7s	remaining: 1.43s
# 163:	learn: 0.0009695	total: 1.71s	remaining: 1.42s
# 164:	learn: 0.0009695	total: 1.72s	remaining: 1.41s
# 165:	learn: 0.0009695	total: 1.73s	remaining: 1.4s
# 166:	learn: 0.0009695	total: 1.74s	remaining: 1.39s
# 167:	learn: 0.0009695	total: 1.75s	remaining: 1.37s
# 168:	learn: 0.0009695	total: 1.76s	remaining: 1.36s
# 169:	learn: 0.0009695	total: 1.77s	remaining: 1.35s
# 170:	learn: 0.0009695	total: 1.78s	remaining: 1.34s
# 171:	learn: 0.0009695	total: 1.79s	remaining: 1.33s
# 172:	learn: 0.0009695	total: 1.8s	remaining: 1.32s
# 173:	learn: 0.0009695	total: 1.8s	remaining: 1.31s
# 174:	learn: 0.0009695	total: 1.81s	remaining: 1.3s
# 175:	learn: 0.0009695	total: 1.82s	remaining: 1.28s
# 176:	learn: 0.0009695	total: 1.83s	remaining: 1.27s
# 177:	learn: 0.0009695	total: 1.84s	remaining: 1.26s
# 178:	learn: 0.0009695	total: 1.85s	remaining: 1.25s
# 179:	learn: 0.0009695	total: 1.86s	remaining: 1.24s
# 180:	learn: 0.0009695	total: 1.87s	remaining: 1.23s
# 181:	learn: 0.0009695	total: 1.88s	remaining: 1.22s
# 182:	learn: 0.0009695	total: 1.89s	remaining: 1.21s
# 183:	learn: 0.0009695	total: 1.9s	remaining: 1.2s
# 184:	learn: 0.0009695	total: 1.91s	remaining: 1.19s
# 185:	learn: 0.0009695	total: 1.92s	remaining: 1.18s
# 186:	learn: 0.0009695	total: 1.93s	remaining: 1.17s
# 187:	learn: 0.0009694	total: 1.94s	remaining: 1.16s
# 188:	learn: 0.0009694	total: 1.95s	remaining: 1.14s
# 189:	learn: 0.0009694	total: 1.96s	remaining: 1.13s
# 190:	learn: 0.0009694	total: 1.97s	remaining: 1.12s
# 191:	learn: 0.0009694	total: 1.98s	remaining: 1.11s
# 192:	learn: 0.0009694	total: 1.99s	remaining: 1.1s
# 193:	learn: 0.0009694	total: 2s	remaining: 1.09s
# 194:	learn: 0.0009694	total: 2.01s	remaining: 1.08s
# 195:	learn: 0.0009694	total: 2.02s	remaining: 1.07s
# 196:	learn: 0.0009694	total: 2.02s	remaining: 1.06s
# 197:	learn: 0.0009694	total: 2.03s	remaining: 1.05s
# 198:	learn: 0.0009694	total: 2.04s	remaining: 1.04s
# 199:	learn: 0.0009694	total: 2.05s	remaining: 1.03s
# 200:	learn: 0.0009694	total: 2.06s	remaining: 1.02s
# 201:	learn: 0.0009694	total: 2.07s	remaining: 1s
# 202:	learn: 0.0009694	total: 2.08s	remaining: 995ms
# 203:	learn: 0.0009694	total: 2.09s	remaining: 984ms
# 204:	learn: 0.0009694	total: 2.1s	remaining: 974ms
# 205:	learn: 0.0009694	total: 2.11s	remaining: 963ms
# 206:	learn: 0.0009694	total: 2.12s	remaining: 952ms
# 207:	learn: 0.0009694	total: 2.13s	remaining: 942ms
# 208:	learn: 0.0009694	total: 2.14s	remaining: 931ms
# 209:	learn: 0.0009694	total: 2.15s	remaining: 920ms
# 210:	learn: 0.0009694	total: 2.16s	remaining: 910ms
# 211:	learn: 0.0009694	total: 2.17s	remaining: 899ms
# 212:	learn: 0.0009694	total: 2.17s	remaining: 889ms
# 213:	learn: 0.0009694	total: 2.19s	remaining: 878ms
# 214:	learn: 0.0009694	total: 2.19s	remaining: 868ms
# 215:	learn: 0.0009694	total: 2.2s	remaining: 857ms
# 216:	learn: 0.0009694	total: 2.21s	remaining: 847ms
# 217:	learn: 0.0009694	total: 2.22s	remaining: 836ms
# 218:	learn: 0.0009694	total: 2.23s	remaining: 826ms
# 219:	learn: 0.0009694	total: 2.24s	remaining: 815ms
# 220:	learn: 0.0009694	total: 2.25s	remaining: 805ms
# 221:	learn: 0.0009694	total: 2.26s	remaining: 794ms
# 222:	learn: 0.0009694	total: 2.27s	remaining: 784ms
# 223:	learn: 0.0009694	total: 2.28s	remaining: 773ms
# 224:	learn: 0.0009694	total: 2.29s	remaining: 763ms
# 225:	learn: 0.0009694	total: 2.3s	remaining: 752ms
# 226:	learn: 0.0009694	total: 2.31s	remaining: 742ms
# 227:	learn: 0.0009694	total: 2.32s	remaining: 732ms
# 228:	learn: 0.0009694	total: 2.33s	remaining: 721ms
# 229:	learn: 0.0009694	total: 2.33s	remaining: 711ms
# 230:	learn: 0.0009694	total: 2.35s	remaining: 700ms
# 231:	learn: 0.0009694	total: 2.35s	remaining: 690ms
# 232:	learn: 0.0009694	total: 2.36s	remaining: 680ms
# 233:	learn: 0.0009694	total: 2.37s	remaining: 670ms
# 234:	learn: 0.0009693	total: 2.38s	remaining: 660ms
# 235:	learn: 0.0009693	total: 2.4s	remaining: 650ms
# 236:	learn: 0.0009692	total: 2.4s	remaining: 639ms
# 237:	learn: 0.0009692	total: 2.42s	remaining: 629ms
# 238:	learn: 0.0009692	total: 2.42s	remaining: 619ms
# 239:	learn: 0.0009691	total: 2.44s	remaining: 609ms
# 240:	learn: 0.0009691	total: 2.44s	remaining: 599ms
# 241:	learn: 0.0009691	total: 2.45s	remaining: 588ms
# 242:	learn: 0.0009691	total: 2.46s	remaining: 578ms
# 243:	learn: 0.0009691	total: 2.47s	remaining: 568ms
# 244:	learn: 0.0009691	total: 2.48s	remaining: 557ms
# 245:	learn: 0.0009691	total: 2.49s	remaining: 547ms
# 246:	learn: 0.0009691	total: 2.5s	remaining: 537ms
# 247:	learn: 0.0009691	total: 2.51s	remaining: 527ms
# 248:	learn: 0.0009691	total: 2.52s	remaining: 516ms
# 249:	learn: 0.0009691	total: 2.53s	remaining: 506ms
# 250:	learn: 0.0009691	total: 2.54s	remaining: 496ms
# 251:	learn: 0.0009691	total: 2.55s	remaining: 486ms
# 252:	learn: 0.0009691	total: 2.56s	remaining: 476ms
# 253:	learn: 0.0009691	total: 2.57s	remaining: 466ms
# 254:	learn: 0.0009691	total: 2.58s	remaining: 455ms
# 255:	learn: 0.0009691	total: 2.59s	remaining: 445ms
# 256:	learn: 0.0009691	total: 2.6s	remaining: 435ms
# 257:	learn: 0.0009691	total: 2.61s	remaining: 425ms
# 258:	learn: 0.0009691	total: 2.62s	remaining: 415ms
# 259:	learn: 0.0009691	total: 2.63s	remaining: 404ms
# 260:	learn: 0.0009691	total: 2.64s	remaining: 394ms
# 261:	learn: 0.0009691	total: 2.65s	remaining: 384ms
# 262:	learn: 0.0009691	total: 2.66s	remaining: 374ms
# 263:	learn: 0.0009691	total: 2.67s	remaining: 364ms
# 264:	learn: 0.0009691	total: 2.68s	remaining: 354ms
# 265:	learn: 0.0009691	total: 2.69s	remaining: 344ms
# 266:	learn: 0.0009691	total: 2.7s	remaining: 333ms
# 267:	learn: 0.0009691	total: 2.71s	remaining: 323ms
# 268:	learn: 0.0009691	total: 2.72s	remaining: 313ms
# 269:	learn: 0.0009691	total: 2.73s	remaining: 303ms
# 270:	learn: 0.0009691	total: 2.74s	remaining: 293ms
# 271:	learn: 0.0009691	total: 2.75s	remaining: 283ms
# 272:	learn: 0.0009691	total: 2.76s	remaining: 273ms
# 273:	learn: 0.0009691	total: 2.77s	remaining: 263ms
# 274:	learn: 0.0009691	total: 2.78s	remaining: 253ms
# 275:	learn: 0.0009691	total: 2.79s	remaining: 243ms
# 276:	learn: 0.0009691	total: 2.8s	remaining: 233ms
# 277:	learn: 0.0009691	total: 2.81s	remaining: 222ms
# 278:	learn: 0.0009691	total: 2.82s	remaining: 212ms
# 279:	learn: 0.0009691	total: 2.83s	remaining: 202ms
# 280:	learn: 0.0009691	total: 2.84s	remaining: 192ms
# 281:	learn: 0.0009691	total: 2.85s	remaining: 182ms
# 282:	learn: 0.0009691	total: 2.86s	remaining: 172ms
# 283:	learn: 0.0009691	total: 2.87s	remaining: 162ms
# 284:	learn: 0.0009691	total: 2.88s	remaining: 151ms
# 285:	learn: 0.0009691	total: 2.89s	remaining: 141ms
# 286:	learn: 0.0009691	total: 2.9s	remaining: 131ms
# 287:	learn: 0.0009691	total: 2.91s	remaining: 121ms
# 288:	learn: 0.0009691	total: 2.92s	remaining: 111ms
# 289:	learn: 0.0009691	total: 2.92s	remaining: 101ms
# 290:	learn: 0.0009691	total: 2.94s	remaining: 90.8ms
# 291:	learn: 0.0009691	total: 2.94s	remaining: 80.7ms
# 292:	learn: 0.0009691	total: 2.95s	remaining: 70.6ms
# 293:	learn: 0.0009691	total: 2.96s	remaining: 60.5ms
# 294:	learn: 0.0009691	total: 2.97s	remaining: 50.4ms
# 295:	learn: 0.0009691	total: 2.98s	remaining: 40.3ms
# 296:	learn: 0.0009691	total: 2.99s	remaining: 30.2ms
# 297:	learn: 0.0009691	total: 3s	remaining: 20.2ms
# 298:	learn: 0.0009691	total: 3.01s	remaining: 10.1ms
# 299:	learn: 0.0009691	total: 3.02s	remaining: 0us
# cat 1.0 1.0
# [[ 2950     0]
#  [    0 57882]]

# %%
import xgboost 
xgb = xgboost.XGBClassifier()
xgb.fit(X_train, y_train, eval_metric="auc")
# Out:
# c:\Users\AI06\anaconda3\envs\ml\lib\site-packages\xgboost\sklearn.py:861: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_bin=256, max_cat_threshold=64, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %%
# 보팅
vot_clf = VotingClassifier(estimators=[(
    "lr", lr_clf), ("xgb", xgb_clf), ("gbm", gb_clf), ("ada", ada_clf)], voting="soft")

# %%
model("vot_clf", vot_clf)
# Out:
# [16:27:50] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "scoring" } are not used.
#
# [16:28:00] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "scoring" } are not used.
#
# [16:28:08] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "scoring" } are not used.
#
# [16:28:16] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "scoring" } are not used.
#
# [16:28:24] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "scoring" } are not used.
#
# [16:28:32] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "scoring" } are not used.
#
# vot_clf 1.0 1.0
# [[ 2950     0]
#  [    0 57882]]

# %% [markdown]
# ### 하이퍼파라미터 튜닝

# %% [markdown]
# #### 예측 및 제출

# %%
def test(model):
    test_pred = model.predict(X_test)
    test_prob = model.predict_proba(X_test)
    
    pred = pd.DataFrame(test_pred)
    pred['test_prob'] = test_prob[:, 1]
    
    for i in range(len(pred)):
        if pred[0][i] == 0:
            pred[0][i] = 1 - pred['test_prob'][i]
            
    submission = pd.read_csv("sample_submission.csv")
    submission['move_out'] = pred['test_prob']
    
    return submission

# %%
file = test(xgb)
file.to_csv("xgb2.csv", index=False)
# Out:
# C:\Users\AI06\AppData\Local\Temp\ipykernel_12584\1319989964.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred[0][i] = 1 - pred['test_prob'][i]

# %%
file
# Out:
#           id  move_out
# 0      77315  0.999938
# 1       9515  1.000000
# 2       1668  0.999999
# 3      57273  1.000000
# 4      19049  0.999999
# ...      ...       ...
# 26067  81241  1.000000
# 26068  83076  1.000000
# 26069  25820  0.999977
# 26070  36133  0.999999
# 26071    680  0.999998
#
# [26072 rows x 2 columns]
